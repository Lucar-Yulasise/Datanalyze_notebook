# %% [markdown]
# # pandas的拼接操作

# %% [markdown]
# pandas的拼接分为两种：
# - 级联：pd.concat, pd.append
# - 合并：pd.merge, pd.join

# %% [markdown]
# ## 0. 回顾numpy的级联

# %%
import numpy as np

# %% [markdown]
# ============================================
#
# 练习12：
#
# 1. 生成2个3*3的矩阵，对其分别进行两个维度上的级联
#
# ============================================

# %%
nd1 = np.random.randint(0,10,size=(3,3))
nd2 = np.random.randint(0,10,size=(3,3))
print(nd1)
print(nd2)
# Out:
# [[8 2 4]
#  [3 6 9]
#  [3 4 1]]
# [[7 4 6]
#  [4 4 5]
#  [9 9 4]]

# %%
np.concatenate([nd1,nd2],axis=1)
# Out:
# array([[8, 2, 4, 7, 4, 6],
#        [3, 6, 9, 4, 4, 5],
#        [3, 4, 1, 9, 9, 4]])

# %%
nd3 = np.random.randint(0,10,size=3)
nd3
# Out:
# array([3, 5, 4])

# %%
np.concatenate([nd1,nd3]) # 维度不一致，无法级联
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-871caaeeb895> in <module>()
# ----> 1 np.concatenate([nd1,nd3])
#
# ValueError: all the input arrays must have same number of dimensions

# %%
nd4 = np.random.randint(0,10,size=(3,2))
nd4
# Out:
# array([[4, 0],
#        [8, 0],
#        [5, 8]])

# %%
np.concatenate([nd1,nd4],axis=1)
# Out:
# array([[8, 2, 4, 4, 0],
#        [3, 6, 9, 8, 0],
#        [3, 4, 1, 5, 8]])

# %%
import pandas as pd
from pandas import DataFrame,Series

# %%
# 为了后面创建数据表方便，定义一个函数，用于创建DataFrame
def make_df(rows,cols):
    
    data = {c:[c+str(i) for i in rows] for c in cols}
    
    return DataFrame(data,index=rows,columns=cols)

# %%
make_df([1,2,3],["a","b"])
# Out:
#     a   b
# 1  a1  b1
# 2  a2  b2
# 3  a3  b3

# %%
df1 = make_df([1,2,3],list("abc"))
df1
# Out:
#     a   b   c
# 1  a1  b1  c1
# 2  a2  b2  c2
# 3  a3  b3  c3

# %%
df2 = make_df([4,5,6],list("abc"))
df2
# Out:
#     a   b   c
# 4  a4  b4  c4
# 5  a5  b5  c5
# 6  a6  b6  c6

# %% [markdown]
# ## 1. 使用pd.concat()级联

# %% [markdown]
# pandas使用pd.concat函数，与np.concatenate函数类似，只是多了一些参数：
# ```
# pd.concat(objs, axis=0, join='outer', join_axes=None, ignore_index=False,
#           keys=None, levels=None, names=None, verify_integrity=False,
#           copy=True)
# ```

# %% [markdown]
# ### 1)  简单级联

# %%
pd.concat([df1,df2],axis=0)
# Out:
#     a   b   c
# 1  a1  b1  c1
# 2  a2  b2  c2
# 3  a3  b3  c3
# 4  a4  b4  c4
# 5  a5  b5  c5
# 6  a6  b6  c6

# %%
# 列级联
pd.concat([df1,df2],axis=1) # df的级联遵从自动补全机制
# Out:
#      a    b    c    a    b    c
# 1   a1   b1   c1  NaN  NaN  NaN
# 2   a2   b2   c2  NaN  NaN  NaN
# 3   a3   b3   c3  NaN  NaN  NaN
# 4  NaN  NaN  NaN   a4   b4   c4
# 5  NaN  NaN  NaN   a5   b5   c5
# 6  NaN  NaN  NaN   a6   b6   c6

# %%
df1
# Out:
#     a   b   c
# 1  a1  b1  c1
# 2  a2  b2  c2
# 3  a3  b3  c3

# %%
df3 = make_df([1,2,4],list("bcd"))
df3
# Out:
#     b   c   d
# 1  b1  c1  d1
# 2  b2  c2  d2
# 4  b4  c4  d4

# %%
pd.concat([df1,df3],axis=0) # 行级联补列
# Out:
#      a   b   c    d
# 1   a1  b1  c1  NaN
# 2   a2  b2  c2  NaN
# 3   a3  b3  c3  NaN
# 1  NaN  b1  c1   d1
# 2  NaN  b2  c2   d2
# 4  NaN  b4  c4   d4

# %%
pd.concat([df1,df3],axis=1)
# Out:
#      a    b    c    b    c    d
# 1   a1   b1   c1   b1   c1   d1
# 2   a2   b2   c2   b2   c2   d2
# 3   a3   b3   c3  NaN  NaN  NaN
# 4  NaN  NaN  NaN   b4   c4   d4

# %% [markdown]
# 解决行标（或者列标）冲突的问题

# %%
#1) 选择ignore_index为忽略索引，索引将从0开始重新排列
pd.concat([df1,df3],axis=0,ignore_index=True)
# Out:
#      a   b   c    d
# 0   a1  b1  c1  NaN
# 1   a2  b2  c2  NaN
# 2   a3  b3  c3  NaN
# 3  NaN  b1  c1   d1
# 4  NaN  b2  c2   d2
# 5  NaN  b4  c4   d4

# %%
#2) 选择使用多层索引
pd.concat([df1,df3],axis=0,keys=["小名","小黄"])
# Out:
#         a   b   c    d
# 小名 1   a1  b1  c1  NaN
#    2   a2  b2  c2  NaN
#    3   a3  b3  c3  NaN
# 小黄 1  NaN  b1  c1   d1
#    2  NaN  b2  c2   d2
#    4  NaN  b4  c4   d4

# %% [markdown]
# ============================================
#
# 练习13：
#
# 1. 想一想级联的应用场景？
#
# 2. 使用昨天的知识，建立一个期中考试张三、李四的成绩表ddd
#
# 3. 假设新增考试学科"计算机"，如何实现？
#
# 4. 新增王老五同学的成绩，如何实现？
#
# ============================================

# %% [markdown]
# ### 2) 不匹配级联

# %% [markdown]
# 不匹配指的是级联的维度的索引不一致。例如纵向级联时列索引不一致，横向级联时行索引不一致

# %%
df1
# Out:
#     a   b   c
# 1  a1  b1  c1
# 2  a2  b2  c2
# 3  a3  b3  c3

# %%
df4 = make_df([3,4,5,6],list("abcd"))
df4
# Out:
#     a   b   c   d
# 3  a3  b3  c3  d3
# 4  a4  b4  c4  d4
# 5  a5  b5  c5  d5
# 6  a6  b6  c6  d6

# %% [markdown]
# 1） 外连接

# %%
pd.concat([df1,df4],axis=0,join="outer")
# Out:
#     a   b   c    d
# 1  a1  b1  c1  NaN
# 2  a2  b2  c2  NaN
# 3  a3  b3  c3  NaN
# 3  a3  b3  c3   d3
# 4  a4  b4  c4   d4
# 5  a5  b5  c5   d5
# 6  a6  b6  c6   d6

# %%
pd.concat([df1,df2],axis=1,join="outer")
# join代表连接方式，默认是outer，即外连接
# 对不一致的地方进行补NaN
# Out:
#      a    b    c    a    b    c
# 1   a1   b1   c1  NaN  NaN  NaN
# 2   a2   b2   c2  NaN  NaN  NaN
# 3   a3   b3   c3  NaN  NaN  NaN
# 4  NaN  NaN  NaN   a4   b4   c4
# 5  NaN  NaN  NaN   a5   b5   c5
# 6  NaN  NaN  NaN   a6   b6   c6

# %% [markdown]
# 2）内连接

# %%
pd.concat([df1,df4],axis=0,join="inner")
# Out:
#     a   b   c
# 1  a1  b1  c1
# 2  a2  b2  c2
# 3  a3  b3  c3
# 3  a3  b3  c3
# 4  a4  b4  c4
# 5  a5  b5  c5
# 6  a6  b6  c6

# %%
pd.concat([df1,df4],axis=1,join="inner")
# join为inner的时候是内连接，把索引不一致的地方剔除掉
# Out:
#     a   b   c   a   b   c   d
# 3  a3  b3  c3  a3  b3  c3  d3

# %% [markdown]
# - 连接指定轴 join_axes

# %%
df5 = make_df([5,6,7,8],list("abde"))
df5
# Out:
#     a   b   d   e
# 5  a5  b5  d5  e5
# 6  a6  b6  d6  e6
# 7  a7  b7  d7  e7
# 8  a8  b8  d8  e8

# %%
pd.concat([df1,df4,df5],join_axes=[pd.Index(["a","e"])])
# Out:
#     a    e
# 1  a1  NaN
# 2  a2  NaN
# 3  a3  NaN
# 3  a3  NaN
# 4  a4  NaN
# 5  a5  NaN
# 6  a6  NaN
# 5  a5   e5
# 6  a6   e6
# 7  a7   e7
# 8  a8   e8

# %%
pd.concat([df1,df4,df5],axis=1,join_axes=[df1.index])
# Out:
#     a   b   c    a    b    c    d    a    b    d    e
# 1  a1  b1  c1  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2  a2  b2  c2  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3  a3  b3  c3   a3   b3   c3   d3  NaN  NaN  NaN  NaN

# %%
pd.concat([df1,df2,df3,df4],axis=0,join_axes=[pd.Index(["d"])])
# Out:
#      d
# 1  NaN
# 2  NaN
# 3  NaN
# 4  NaN
# 5  NaN
# 6  NaN
# 1   d1
# 2   d2
# 4   d4
# 3   d3
# 4   d4
# 5   d5
# 6   d6

# %% [markdown]
# ============================================
#
# 练习14：
#
#     假设【期末】考试ddd2的成绩没有张三的，只有李四、王老五、赵小六的，使用多种方法级联
#
# ============================================

# %% [markdown]
# ### 3) 使用append()函数添加

# %% [markdown]
# 由于在后面级联的使用非常普遍，因此有一个函数append专门用于在后面添加

# %% [markdown]
# 列表的append()

# %%
l = [1,2,3,4]
l
# Out:
# [1, 2, 3, 4]

# %%
l.append(9)
l
# Out:
# [1, 2, 3, 4, 9, 9]

# %%
l.append("123")

# %%
l.append(["a","b"])
l
# Out:
# [1, 2, 3, 4, 9, 9, '123', ['a', 'b']]

# %%
df1
# Out:
#     a   b   c
# 1  a1  b1  c1
# 2  a2  b2  c2
# 3  a3  b3  c3

# %%
df1.append("123") # 常数无法级联，也就无法进行append
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-82-23961a96c38e> in <module>()
# ----> 1 df1.append("123")
#
# C:\Anaconda3\lib\site-packages\pandas\core\frame.py in append(self, other, ignore_index, verify_integrity)
#    4545             to_concat = [self, other]
#    4546         return concat(to_concat, ignore_index=ignore_index,
# -> 4547                       verify_integrity=verify_integrity)
#    4548
#    4549     def join(self, other, on=None, how='left', lsuffix='', rsuffix='',
#
# C:\Anaconda3\lib\site-packages\pandas\core\reshape\concat.py in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity, copy)
#     204                        keys=keys, levels=levels, names=names,
#     205                        verify_integrity=verify_integrity,
# --> 206                        copy=copy)
#     207     return op.get_result()
#     208
#
# C:\Anaconda3\lib\site-packages\pandas\core\reshape\concat.py in __init__(self, objs, axis, join, join_axes, keys, levels, names, ignore_index, verify_integrity, copy)
#     261         for obj in objs:
#     262             if not isinstance(obj, NDFrame):
# --> 263                 raise TypeError("cannot concatenate a non-NDFrame object")
#     264
#     265             # consolidate
#
# TypeError: cannot concatenate a non-NDFrame object

# %%
df1.append([12,2,3])
# 如果追加一个列表，会把这个列表直接创建成一个DataFrame，进一步的append
# Out:
#      a    b    c     0
# 1   a1   b1   c1   NaN
# 2   a2   b2   c2   NaN
# 3   a3   b3   c3   NaN
# 0  NaN  NaN  NaN  12.0
# 1  NaN  NaN  NaN   2.0
# 2  NaN  NaN  NaN   3.0

# %%
df4
# Out:
#     a   b   c   d
# 3  a3  b3  c3  d3
# 4  a4  b4  c4  d4
# 5  a5  b5  c5  d5
# 6  a6  b6  c6  d6

# %%
df1.append(df4)
# DataFrame的append相当于进行行级联
# Out:
#     a   b   c    d
# 1  a1  b1  c1  NaN
# 2  a2  b2  c2  NaN
# 3  a3  b3  c3  NaN
# 3  a3  b3  c3   d3
# 4  a4  b4  c4   d4
# 5  a5  b5  c5   d5
# 6  a6  b6  c6   d6

# %% [markdown]
# ============================================
#
# 练习15：
#
#     新建一个只有张三李四王老五的期末考试成绩单ddd3，使用append()与期中考试成绩表ddd级联
#
# ============================================

# %% [markdown]
# ## 2. 使用pd.merge()合并

# %% [markdown]
# merge与concat的区别在于，merge需要依据某一共同的行或列来进行合并
#
# 使用pd.merge()合并时，会自动根据两者相同column名称的那一列，作为key来进行合并。
#
# 注意每一列元素的顺序不要求一致

# %% [markdown]
# ###  1) 一对一合并

# %% [markdown]
# 公共属性中，如果对应的值是一一对应关系，我们称之为一对一合并

# %%
df1 = DataFrame({
    "name":["小明","小黄","小绿","小白"],
    "age":[18,28,30,40],
    "job":["student","driver","seller","boss"]
},index=list("abcd"))
df1
# Out:
#    age      job name
# a   18  student   小明
# b   28   driver   小黄
# c   30   seller   小绿
# d   40     boss   小白

# %%
df2 = DataFrame({
    "name":["小明","小黄","小绿","小白"],
    "home":["北京","上海","杭州","新加坡"],
    "phone":[110,120,119,999]
},index=list("abcd"))
df2
# Out:
#   home name  phone
# a   北京   小明    110
# b   上海   小黄    120
# c   杭州   小绿    119
# d  新加坡   小白    999

# %%
pd.concat([df1,df2],axis=1)
# Out:
#    age      job name home name  phone
# a   18  student   小明   北京   小明    110
# b   28   driver   小黄   上海   小黄    120
# c   30   seller   小绿   杭州   小绿    119
# d   40     boss   小白  新加坡   小白    999

# %%
pd.merge(df1,df2)
# Out:
#    age      job name home  phone
# 0   18  student   小明   北京    110
# 1   28   driver   小黄   上海    120
# 2   30   seller   小绿   杭州    119
# 3   40     boss   小白  新加坡    999

# %%
df3 = DataFrame({
    "姓名":["小明","小黄","小绿","小白"],
    "home":["北京","上海","杭州","新加坡"],
    "phone":[110,120,119,999]
},index=list("abcd"))
df3
# Out:
#   home  phone  姓名
# a   北京    110  小明
# b   上海    120  小黄
# c   杭州    119  小绿
# d  新加坡    999  小白

# %%
pd.merge(df1,df3)
# Out:
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# <ipython-input-93-139693c2ac2b> in <module>()
# ----> 1 pd.merge(df1,df3)
#
# C:\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator)
#      51                          right_on=right_on, left_index=left_index,
#      52                          right_index=right_index, sort=sort, suffixes=suffixes,
# ---> 53                          copy=copy, indicator=indicator)
#      54     return op.get_result()
#      55
#
# C:\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator)
#     551             warnings.warn(msg, UserWarning)
#     552
# --> 553         self._validate_specification()
#     554
#     555         # note this function has side effects
#
# C:\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in _validate_specification(self)
#     926                     self.right.columns)
#     927                 if len(common_cols) == 0:
# --> 928                     raise MergeError('No common columns to perform merge on')
#     929                 if not common_cols.is_unique:
#     930                     raise MergeError("Data columns not unique: %s"
#
# MergeError: No common columns to perform merge on

# %%
df1.merge(df2,axis=0) # merge没有这个参数，合并针对的是列
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-95-ed1246122aa6> in <module>()
# ----> 1 df1.merge(df2,axis=0)
#
# TypeError: merge() got an unexpected keyword argument 'axis'

# %% [markdown]
# 【注意】
#
#     1）合并不能操作列，针对于行
#     2）合并的条件：要有公共的属性（即列）
#     3）合并的时候把公共的属性对应的值并在一起

# %% [markdown]
# ### 2) 多对一合并

# %%
df3 = DataFrame({
    "name":["小明","小黄","小绿","小白","小明","小绿","小明","小黄"],
    "home":["北京","上海","杭州","新加坡","日本","韩国","美国","深圳"],
    "phone":[110,120,119,999,10086,10010,4004000,123456]
},index=list("abcdefgh"))
df3
# Out:
#   home name    phone
# a   北京   小明      110
# b   上海   小黄      120
# c   杭州   小绿      119
# d  新加坡   小白      999
# e   日本   小明    10086
# f   韩国   小绿    10010
# g   美国   小明  4004000
# h   深圳   小黄   123456

# %%
df1
# Out:
#    age      job name
# a   18  student   小明
# b   28   driver   小黄
# c   30   seller   小绿
# d   40     boss   小白

# %%
df1.merge(df3)
# Out:
#    age      job name home    phone
# 0   18  student   小明   北京      110
# 1   18  student   小明   日本    10086
# 2   18  student   小明   美国  4004000
# 3   28   driver   小黄   上海      120
# 4   28   driver   小黄   深圳   123456
# 5   30   seller   小绿   杭州      119
# 6   30   seller   小绿   韩国    10010
# 7   40     boss   小白  新加坡      999

# %% [markdown]
# 一对多：在某个公共属性中表1中的某个值，在表2中有多个和他对应
#
# 合并规则：把表1中对应的那些行复制到表2的数量，然后对应合并

# %% [markdown]
# ### 3) 多对多合并

# %%
df3
# Out:
#   home name    phone
# a   北京   小明      110
# b   上海   小黄      120
# c   杭州   小绿      119
# d  新加坡   小白      999
# e   日本   小明    10086
# f   韩国   小绿    10010
# g   美国   小明  4004000
# h   深圳   小黄   123456

# %%
df4 = DataFrame({
    "name":["小明","小黄","小绿","小白","小明","小黄","小白"],
    "age":[18,28,30,40,20,18,25],
    "job":["student","driver","seller","boss","医生","演员","男演员"]
},index=list("abcdefg"))
df4
# Out:
#    age      job name
# a   18  student   小明
# b   28   driver   小黄
# c   30   seller   小绿
# d   40     boss   小白
# e   20       医生   小明
# f   18       演员   小黄
# g   25      男演员   小白

# %%
df3.merge(df4)
# Out:
#    home name    phone  age      job
# 0    北京   小明      110   18  student
# 1    北京   小明      110   20       医生
# 2    日本   小明    10086   18  student
# 3    日本   小明    10086   20       医生
# 4    美国   小明  4004000   18  student
# 5    美国   小明  4004000   20       医生
# 6    上海   小黄      120   28   driver
# 7    上海   小黄      120   18       演员
# 8    深圳   小黄   123456   28   driver
# 9    深圳   小黄   123456   18       演员
# 10   杭州   小绿      119   30   seller
# 11   韩国   小绿    10010   30   seller
# 12  新加坡   小白      999   40     boss
# 13  新加坡   小白      999   25      男演员

# %% [markdown]
# 多对多：表1中有多个相同值，表2中和这个值相同的也有多个
#
# 合并：分别拿出表1中所有的值，去和表2中对应的值匹配生成一个新的行，最终生成的数据个条数是两者的乘积

# %% [markdown]
# ### 4) key的规范化

# %% [markdown]
# - 使用on=显式指定哪一列为key,当有多个key相同时使用

# %%
df1
# Out:
#    age      job name
# a   18  student   小明
# b   28   driver   小黄
# c   30   seller   小绿
# d   40     boss   小白

# %%
df5 = DataFrame({
    "name":["小明","小黄","小绿","小白","小明","小绿","小明","小黄"],
    "home":["北京","上海","杭州","新加坡","日本","韩国","美国","深圳"],
    "phone":[110,120,119,999,10086,10010,4004000,123456],
    "age":[18,19,20,21,22,23,24,25]
},index=list("abcdefgh"))
df5
# Out:
#    age home name    phone
# a   18   北京   小明      110
# b   19   上海   小黄      120
# c   20   杭州   小绿      119
# d   21  新加坡   小白      999
# e   22   日本   小明    10086
# f   23   韩国   小绿    10010
# g   24   美国   小明  4004000
# h   25   深圳   小黄   123456

# %%
df4.merge(df5)
# 现在有两个公共的属性，在合并的时候要参考两个key值
# Out:
#    age      job name home  phone
# 0   18  student   小明   北京    110

# %% [markdown]
# - 使用left_on和right_on指定左右两边的列作为key，当左右两边的key都不想等时使用

# %%
# 如果有多个相同的属性，我们可以制定以哪几个属性为基准进行合并
df4.merge(df5,on="name",suffixes=["_真实","_虚假"])
# Out:
#     age_真实      job name  age_虚假 home    phone
# 0       18  student   小明      18   北京      110
# 1       18  student   小明      22   日本    10086
# 2       18  student   小明      24   美国  4004000
# 3       20       医生   小明      18   北京      110
# 4       20       医生   小明      22   日本    10086
# 5       20       医生   小明      24   美国  4004000
# 6       28   driver   小黄      19   上海      120
# 7       28   driver   小黄      25   深圳   123456
# 8       18       演员   小黄      19   上海      120
# 9       18       演员   小黄      25   深圳   123456
# 10      30   seller   小绿      20   杭州      119
# 11      30   seller   小绿      23   韩国    10010
# 12      40     boss   小白      21  新加坡      999
# 13      25      男演员   小白      21  新加坡      999

# %%
df1
# Out:
#    age      job name
# a   18  student   小明
# b   28   driver   小黄
# c   30   seller   小绿
# d   40     boss   小白

# %%
df6 = DataFrame({
    "姓名":["小明","小黄","小绿","小白","小明","小绿","小明","小黄"],
    "家乡":["北京","上海","杭州","新加坡","日本","韩国","美国","深圳"],
    "电话":[110,120,119,999,10086,10010,4004000,"小明"]
},index=list("abcdefgh"))
df6
# Out:
#    姓名   家乡       电话
# a  小明   北京      110
# b  小黄   上海      120
# c  小绿   杭州      119
# d  小白  新加坡      999
# e  小明   日本    10086
# f  小绿   韩国    10010
# g  小明   美国  4004000
# h  小黄   深圳       小明

# %%
df1.merge(df6,left_on="name",right_on="姓名")
# 没有公共的属性时，可以采用left_on和right_on去指定左侧和右侧出那个属性来合并
# 由于左右不是公共属性，不能并在一起
# Out:
#    age      job name  姓名   家乡       电话
# 0   18  student   小明  小明   北京      110
# 1   18  student   小明  小明   日本    10086
# 2   18  student   小明  小明   美国  4004000
# 3   28   driver   小黄  小黄   上海      120
# 4   28   driver   小黄  小黄   深圳       小明
# 5   30   seller   小绿  小绿   杭州      119
# 6   30   seller   小绿  小绿   韩国    10010
# 7   40     boss   小白  小白  新加坡      999

# %%
df1.merge(df6,left_on="name",right_on="家乡")
# Out:
# Empty DataFrame
# Columns: [age, job, name, 姓名, 家乡, 电话]
# Index: []

# %% [markdown]
# ============================================
#
# 练习16：
#
# 1. 假设有两份成绩单，除了ddd是张三李四王老五之外，还有ddd4是张三和赵小六的成绩单，如何合并？
#
# 2. 如果ddd4中张三的名字被打错了，成为了张十三，怎么办？
#
# 3. 自行练习多对一，多对多的情况
#
# 4. 自学left_index,right_index
#
# ============================================

# %% [markdown]
# 推广：left_index和right_index

# %%
df1.merge(df6,left_index=True,right_index=True,how="outer")
# Out:
#     age      job name  姓名   家乡       电话
# a  18.0  student   小明  小明   北京      110
# b  28.0   driver   小黄  小黄   上海      120
# c  30.0   seller   小绿  小绿   杭州      119
# d  40.0     boss   小白  小白  新加坡      999
# e   NaN      NaN  NaN  小明   日本    10086
# f   NaN      NaN  NaN  小绿   韩国    10010
# g   NaN      NaN  NaN  小明   美国  4004000
# h   NaN      NaN  NaN  小黄   深圳       小明

# %%
df1.merge(df6,left_index=True,right_on="姓名",how="inner")
# Out:
# Empty DataFrame
# Columns: [age, job, name, 姓名, 家乡, 电话]
# Index: []

# %% [markdown]
# ### 5) 内合并与外合并

# %%
df1
# Out:
#    age      job name
# a   18  student   小明
# b   28   driver   小黄
# c   30   seller   小绿
# d   40     boss   小白

# %%
df7 = DataFrame({
    "name":["小明","小黄","小绿","小白","Jack","安倍","Obama","李嘉诚"],
    "home":["北京","上海","杭州","新加坡","日本","韩国","美国","深圳"],
    "phone":[110,120,119,999,10086,10010,4004000,"小明"]
},index=list("abcdefgh"))
df7
# Out:
#   home   name    phone
# a   北京     小明      110
# b   上海     小黄      120
# c   杭州     小绿      119
# d  新加坡     小白      999
# e   日本   Jack    10086
# f   韩国     安倍    10010
# g   美国  Obama  4004000
# h   深圳    李嘉诚       小明

# %%
df1.merge(df7)
# Out:
#    age      job name home phone
# 0   18  student   小明   北京   110
# 1   28   driver   小黄   上海   120
# 2   30   seller   小绿   杭州   119
# 3   40     boss   小白  新加坡   999

# %% [markdown]
# - 内合并：只保留两者都有的key（默认模式）

# %%
df1.merge(df7,how="inner")
# how参数代表的是合并的方式默认是"inner"代表内合并
# 两个表里面公共部分保留，不匹配的部分删除
# Out:
#    age      job name home phone
# 0   18  student   小明   北京   110
# 1   28   driver   小黄   上海   120
# 2   30   seller   小绿   杭州   119
# 3   40     boss   小白  新加坡   999

# %% [markdown]
# - 外合并：所有的值全部并在一起，不匹配的地方补NaN

# %%
df1.merge(df7,how="outer")
# Out:
#     age      job   name home    phone
# 0  18.0  student     小明   北京      110
# 1  28.0   driver     小黄   上海      120
# 2  30.0   seller     小绿   杭州      119
# 3  40.0     boss     小白  新加坡      999
# 4   NaN      NaN   Jack   日本    10086
# 5   NaN      NaN     安倍   韩国    10010
# 6   NaN      NaN  Obama   美国  4004000
# 7   NaN      NaN    李嘉诚   深圳       小明

# %% [markdown]
# - 左合并、右合并：how='left'，how='right'，

# %%
df1.merge(df7,how="right")
# left左合并，以左侧表的值为基准，右有左侧没有的地方删除，左侧有右侧没有的地方补Nan
# right右合并，以右侧为基准
# Out:
#     age      job   name home    phone
# 0  18.0  student     小明   北京      110
# 1  28.0   driver     小黄   上海      120
# 2  30.0   seller     小绿   杭州      119
# 3  40.0     boss     小白  新加坡      999
# 4   NaN      NaN   Jack   日本    10086
# 5   NaN      NaN     安倍   韩国    10010
# 6   NaN      NaN  Obama   美国  4004000
# 7   NaN      NaN    李嘉诚   深圳       小明

# %% [markdown]
# ============================================
#
# 练习17：
#
# 1. 如果只有张三赵小六语数英三个科目的成绩，如何合并？
#
# 3. 考虑应用情景，使用多种方式合并ddd与ddd4
#
# ============================================

# %% [markdown]
# ### 6) 列冲突的解决

# %% [markdown]
# 当列冲突时，即有多个列名称相同时，需要使用on=来指定哪一个列作为key，配合suffixes指定冲突列名

# %% [markdown]
# 可以使用suffixes=自己指定后缀

# %% [markdown]
# ============================================
#
# 练习18：
#
#     假设有两个同学都叫李四，ddd5、ddd6都是张三和李四的成绩表，如何合并？
#
# ============================================

# %% [markdown]
# ## 作业
# ## 3. 案例分析：美国各州人口数据分析

# %% [markdown]
# 要点总结：
# - 统一用loc()索引
# - 善于使用.isnull().any()找到存在NaN的列
# - 善于使用.unique()确定该列中哪些key是我们需要的
# - 一般使用外合并、左合并，目的只有一个：宁愿该列是NaN也不要丢弃其他列的信息

# %%
# 导入数据
abb = pd.read_csv("./usapop/state-abbrevs.csv")
areas = pd.read_csv("./usapop/state-areas.csv")
pop = pd.read_csv("./usapop/state-population.csv")

# %%
abb
# Out:
#                    state abbreviation
# 0                Alabama           AL
# 1                 Alaska           AK
# 2                Arizona           AZ
# 3               Arkansas           AR
# 4             California           CA
# 5               Colorado           CO
# 6            Connecticut           CT
# 7               Delaware           DE
# 8   District of Columbia           DC
# 9                Florida           FL
# 10               Georgia           GA
# 11                Hawaii           HI
# 12                 Idaho           ID
# 13              Illinois           IL
# 14               Indiana           IN
# 15                  Iowa           IA
# 16                Kansas           KS
# 17              Kentucky           KY
# 18             Louisiana           LA
# 19                 Maine           ME
# 20               Montana           MT
# 21              Nebraska           NE
# 22                Nevada           NV
# 23         New Hampshire           NH
# 24            New Jersey           NJ
# 25            New Mexico           NM
# 26              New York           NY
# 27        North Carolina           NC
# 28          North Dakota           ND
# 29                  Ohio           OH
# 30              Oklahoma           OK
# 31                Oregon           OR
# 32              Maryland           MD
# 33         Massachusetts           MA
# 34              Michigan           MI
# 35             Minnesota           MN
# 36           Mississippi           MS
# 37              Missouri           MO
# 38          Pennsylvania           PA
# 39          Rhode Island           RI
# 40        South Carolina           SC
# 41          South Dakota           SD
# 42             Tennessee           TN
# 43                 Texas           TX
# 44                  Utah           UT
# 45               Vermont           VT
# 46              Virginia           VA
# 47            Washington           WA
# 48         West Virginia           WV
# 49             Wisconsin           WI
# 50               Wyoming           WY

# %%
areas
# Out:
#                    state  area (sq. mi)
# 0                Alabama          52423
# 1                 Alaska         656425
# 2                Arizona         114006
# 3               Arkansas          53182
# 4             California         163707
# 5               Colorado         104100
# 6            Connecticut           5544
# 7               Delaware           1954
# 8                Florida          65758
# 9                Georgia          59441
# 10                Hawaii          10932
# 11                 Idaho          83574
# 12              Illinois          57918
# 13               Indiana          36420
# 14                  Iowa          56276
# 15                Kansas          82282
# 16              Kentucky          40411
# 17             Louisiana          51843
# 18                 Maine          35387
# 19              Maryland          12407
# 20         Massachusetts          10555
# 21              Michigan          96810
# 22             Minnesota          86943
# 23           Mississippi          48434
# 24              Missouri          69709
# 25               Montana         147046
# 26              Nebraska          77358
# 27                Nevada         110567
# 28         New Hampshire           9351
# 29            New Jersey           8722
# 30            New Mexico         121593
# 31              New York          54475
# 32        North Carolina          53821
# 33          North Dakota          70704
# 34                  Ohio          44828
# 35              Oklahoma          69903
# 36                Oregon          98386
# 37          Pennsylvania          46058
# 38          Rhode Island           1545
# 39        South Carolina          32007
# 40          South Dakota          77121
# 41             Tennessee          42146
# 42                 Texas         268601
# 43                  Utah          84904
# 44               Vermont           9615
# 45              Virginia          42769
# 46            Washington          71303
# 47         West Virginia          24231
# 48             Wisconsin          65503
# 49               Wyoming          97818
# 50  District of Columbia             68
# 51           Puerto Rico           3515

# %%
pop
# Out:
#      state/region     ages  year   population
# 0              AL  under18  2012    1117489.0
# 1              AL    total  2012    4817528.0
# 2              AL  under18  2010    1130966.0
# 3              AL    total  2010    4785570.0
# 4              AL  under18  2011    1125763.0
# 5              AL    total  2011    4801627.0
# 6              AL    total  2009    4757938.0
# 7              AL  under18  2009    1134192.0
# 8              AL  under18  2013    1111481.0
# 9              AL    total  2013    4833722.0
# 10             AL    total  2007    4672840.0
# 11             AL  under18  2007    1132296.0
# 12             AL    total  2008    4718206.0
# 13             AL  under18  2008    1134927.0
# 14             AL    total  2005    4569805.0
# 15             AL  under18  2005    1117229.0
# 16             AL    total  2006    4628981.0
# 17             AL  under18  2006    1126798.0
# 18             AL    total  2004    4530729.0
# 19             AL  under18  2004    1113662.0
# 20             AL    total  2003    4503491.0
# 21             AL  under18  2003    1113083.0
# 22             AL    total  2001    4467634.0
# 23             AL  under18  2001    1120409.0
# 24             AL    total  2002    4480089.0
# 25             AL  under18  2002    1116590.0
# 26             AL  under18  1999    1121287.0
# 27             AL    total  1999    4430141.0
# 28             AL    total  2000    4452173.0
# 29             AL  under18  2000    1122273.0
# ...           ...      ...   ...          ...
# 2514          USA  under18  1999   71946051.0
# 2515          USA    total  2000  282162411.0
# 2516          USA  under18  2000   72376189.0
# 2517          USA    total  1999  279040181.0
# 2518          USA    total  2001  284968955.0
# 2519          USA  under18  2001   72671175.0
# 2520          USA    total  2002  287625193.0
# 2521          USA  under18  2002   72936457.0
# 2522          USA    total  2003  290107933.0
# 2523          USA  under18  2003   73100758.0
# 2524          USA    total  2004  292805298.0
# 2525          USA  under18  2004   73297735.0
# 2526          USA    total  2005  295516599.0
# 2527          USA  under18  2005   73523669.0
# 2528          USA    total  2006  298379912.0
# 2529          USA  under18  2006   73757714.0
# 2530          USA    total  2007  301231207.0
# 2531          USA  under18  2007   74019405.0
# 2532          USA    total  2008  304093966.0
# 2533          USA  under18  2008   74104602.0
# 2534          USA  under18  2013   73585872.0
# 2535          USA    total  2013  316128839.0
# 2536          USA    total  2009  306771529.0
# 2537          USA  under18  2009   74134167.0
# 2538          USA  under18  2010   74119556.0
# 2539          USA    total  2010  309326295.0
# 2540          USA  under18  2011   73902222.0
# 2541          USA    total  2011  311582564.0
# 2542          USA  under18  2012   73708179.0
# 2543          USA    total  2012  313873685.0
#
# [2544 rows x 4 columns]

# %% [markdown]
# ###### 对数据进行整合与清洗

# %% [markdown]
# 1、合并pop和abb两张表

# %%
pop2 = abb.merge(pop,left_on="abbreviation",right_on="state/region",how="outer")

# %%
pop2.head(5) # head是输出前n行，默认是5
# Out:
#      state abbreviation state/region     ages  year  population
# 0  Alabama           AL           AL  under18  2012   1117489.0
# 1  Alabama           AL           AL    total  2012   4817528.0
# 2  Alabama           AL           AL  under18  2010   1130966.0
# 3  Alabama           AL           AL    total  2010   4785570.0
# 4  Alabama           AL           AL  under18  2011   1125763.0

# %%
pop2
# Out:
#         state abbreviation state/region     ages  year   population
# 0     Alabama           AL           AL  under18  2012    1117489.0
# 1     Alabama           AL           AL    total  2012    4817528.0
# 2     Alabama           AL           AL  under18  2010    1130966.0
# 3     Alabama           AL           AL    total  2010    4785570.0
# 4     Alabama           AL           AL  under18  2011    1125763.0
# 5     Alabama           AL           AL    total  2011    4801627.0
# 6     Alabama           AL           AL    total  2009    4757938.0
# 7     Alabama           AL           AL  under18  2009    1134192.0
# 8     Alabama           AL           AL  under18  2013    1111481.0
# 9     Alabama           AL           AL    total  2013    4833722.0
# 10    Alabama           AL           AL    total  2007    4672840.0
# 11    Alabama           AL           AL  under18  2007    1132296.0
# 12    Alabama           AL           AL    total  2008    4718206.0
# 13    Alabama           AL           AL  under18  2008    1134927.0
# 14    Alabama           AL           AL    total  2005    4569805.0
# 15    Alabama           AL           AL  under18  2005    1117229.0
# 16    Alabama           AL           AL    total  2006    4628981.0
# 17    Alabama           AL           AL  under18  2006    1126798.0
# 18    Alabama           AL           AL    total  2004    4530729.0
# 19    Alabama           AL           AL  under18  2004    1113662.0
# 20    Alabama           AL           AL    total  2003    4503491.0
# 21    Alabama           AL           AL  under18  2003    1113083.0
# 22    Alabama           AL           AL    total  2001    4467634.0
# 23    Alabama           AL           AL  under18  2001    1120409.0
# 24    Alabama           AL           AL    total  2002    4480089.0
# 25    Alabama           AL           AL  under18  2002    1116590.0
# 26    Alabama           AL           AL  under18  1999    1121287.0
# 27    Alabama           AL           AL    total  1999    4430141.0
# 28    Alabama           AL           AL    total  2000    4452173.0
# 29    Alabama           AL           AL  under18  2000    1122273.0
# ...       ...          ...          ...      ...   ...          ...
# 2514      NaN          NaN          USA  under18  1999   71946051.0
# 2515      NaN          NaN          USA    total  2000  282162411.0
# 2516      NaN          NaN          USA  under18  2000   72376189.0
# 2517      NaN          NaN          USA    total  1999  279040181.0
# 2518      NaN          NaN          USA    total  2001  284968955.0
# 2519      NaN          NaN          USA  under18  2001   72671175.0
# 2520      NaN          NaN          USA    total  2002  287625193.0
# 2521      NaN          NaN          USA  under18  2002   72936457.0
# 2522      NaN          NaN          USA    total  2003  290107933.0
# 2523      NaN          NaN          USA  under18  2003   73100758.0
# 2524      NaN          NaN          USA    total  2004  292805298.0
# 2525      NaN          NaN          USA  under18  2004   73297735.0
# 2526      NaN          NaN          USA    total  2005  295516599.0
# 2527      NaN          NaN          USA  under18  2005   73523669.0
# 2528      NaN          NaN          USA    total  2006  298379912.0
# 2529      NaN          NaN          USA  under18  2006   73757714.0
# 2530      NaN          NaN          USA    total  2007  301231207.0
# 2531      NaN          NaN          USA  under18  2007   74019405.0
# 2532      NaN          NaN          USA    total  2008  304093966.0
# 2533      NaN          NaN          USA  under18  2008   74104602.0
# 2534      NaN          NaN          USA  under18  2013   73585872.0
# 2535      NaN          NaN          USA    total  2013  316128839.0
# 2536      NaN          NaN          USA    total  2009  306771529.0
# 2537      NaN          NaN          USA  under18  2009   74134167.0
# 2538      NaN          NaN          USA  under18  2010   74119556.0
# 2539      NaN          NaN          USA    total  2010  309326295.0
# 2540      NaN          NaN          USA  under18  2011   73902222.0
# 2541      NaN          NaN          USA    total  2011  311582564.0
# 2542      NaN          NaN          USA  under18  2012   73708179.0
# 2543      NaN          NaN          USA    total  2012  313873685.0
#
# [2544 rows x 6 columns]

# %%
# 删除掉一列简称
pop2.drop("abbreviation",axis=1,inplace=True)
# inplace参数表示是否在原表上修改，True在原表上修改
# False默认，不在原表上修改，生成一个新表返回出来

# %% [markdown]
# 查看数据的缺失情况

# %%
pop2.isnull().any()
# Out:
# state            True
# state/region    False
# ages            False
# year            False
# population       True
# dtype: bool

# %% [markdown]
# 通过上面的检测，发现state属性和population属性有数据缺失
#
# 接下来我们具体来查看缺失情况

# %%
# state的缺失
cond_state = pop2["state"].isnull()
pop2[cond_state]["state/region"].unique() # 输出缺失的那些周的行
# Out:
# array(['PR', 'USA'], dtype=object)

# %% [markdown]
# 我们发现PR和USA这两个简称对应的state没有
#
# 通过分析发现PR代表Puerto Rico，USA代表United States

# %%
# 找到简称为PR的那些行
cond_pr = pop2["state/region"] == "PR"
pop2[cond_pr]
# Out:
#      state state/region     ages  year  population
# 2448   NaN           PR  under18  1990         NaN
# 2449   NaN           PR    total  1990         NaN
# 2450   NaN           PR    total  1991         NaN
# 2451   NaN           PR  under18  1991         NaN
# 2452   NaN           PR    total  1993         NaN
# 2453   NaN           PR  under18  1993         NaN
# 2454   NaN           PR  under18  1992         NaN
# 2455   NaN           PR    total  1992         NaN
# 2456   NaN           PR  under18  1994         NaN
# 2457   NaN           PR    total  1994         NaN
# 2458   NaN           PR    total  1995         NaN
# 2459   NaN           PR  under18  1995         NaN
# 2460   NaN           PR  under18  1996         NaN
# 2461   NaN           PR    total  1996         NaN
# 2462   NaN           PR  under18  1998         NaN
# 2463   NaN           PR    total  1998         NaN
# 2464   NaN           PR    total  1997         NaN
# 2465   NaN           PR  under18  1997         NaN
# 2466   NaN           PR    total  1999         NaN
# 2467   NaN           PR  under18  1999         NaN
# 2468   NaN           PR    total  2000   3810605.0
# 2469   NaN           PR  under18  2000   1089063.0
# 2470   NaN           PR    total  2001   3818774.0
# 2471   NaN           PR  under18  2001   1077566.0
# 2472   NaN           PR    total  2002   3823701.0
# 2473   NaN           PR  under18  2002   1065051.0
# 2474   NaN           PR    total  2004   3826878.0
# 2475   NaN           PR  under18  2004   1035919.0
# 2476   NaN           PR    total  2003   3826095.0
# 2477   NaN           PR  under18  2003   1050615.0
# 2478   NaN           PR    total  2005   3821362.0
# 2479   NaN           PR  under18  2005   1019447.0
# 2480   NaN           PR    total  2006   3805214.0
# 2481   NaN           PR  under18  2006    998543.0
# 2482   NaN           PR    total  2007   3782995.0
# 2483   NaN           PR  under18  2007    973613.0
# 2484   NaN           PR    total  2008   3760866.0
# 2485   NaN           PR  under18  2008    945705.0
# 2486   NaN           PR  under18  2013    814068.0
# 2487   NaN           PR    total  2013   3615086.0
# 2488   NaN           PR    total  2009   3740410.0
# 2489   NaN           PR  under18  2009    920794.0
# 2490   NaN           PR    total  2010   3721208.0
# 2491   NaN           PR  under18  2010    896945.0
# 2492   NaN           PR  under18  2011    869327.0
# 2493   NaN           PR    total  2011   3686580.0
# 2494   NaN           PR  under18  2012    841740.0
# 2495   NaN           PR    total  2012   3651545.0

# %%
pop2["state"][cond_pr] = "Puerto Rico"
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
pop2[cond_pr]
# Out:
#             state state/region     ages  year  population
# 2448  Puerto Rico           PR  under18  1990         NaN
# 2449  Puerto Rico           PR    total  1990         NaN
# 2450  Puerto Rico           PR    total  1991         NaN
# 2451  Puerto Rico           PR  under18  1991         NaN
# 2452  Puerto Rico           PR    total  1993         NaN
# 2453  Puerto Rico           PR  under18  1993         NaN
# 2454  Puerto Rico           PR  under18  1992         NaN
# 2455  Puerto Rico           PR    total  1992         NaN
# 2456  Puerto Rico           PR  under18  1994         NaN
# 2457  Puerto Rico           PR    total  1994         NaN
# 2458  Puerto Rico           PR    total  1995         NaN
# 2459  Puerto Rico           PR  under18  1995         NaN
# 2460  Puerto Rico           PR  under18  1996         NaN
# 2461  Puerto Rico           PR    total  1996         NaN
# 2462  Puerto Rico           PR  under18  1998         NaN
# 2463  Puerto Rico           PR    total  1998         NaN
# 2464  Puerto Rico           PR    total  1997         NaN
# 2465  Puerto Rico           PR  under18  1997         NaN
# 2466  Puerto Rico           PR    total  1999         NaN
# 2467  Puerto Rico           PR  under18  1999         NaN
# 2468  Puerto Rico           PR    total  2000   3810605.0
# 2469  Puerto Rico           PR  under18  2000   1089063.0
# 2470  Puerto Rico           PR    total  2001   3818774.0
# 2471  Puerto Rico           PR  under18  2001   1077566.0
# 2472  Puerto Rico           PR    total  2002   3823701.0
# 2473  Puerto Rico           PR  under18  2002   1065051.0
# 2474  Puerto Rico           PR    total  2004   3826878.0
# 2475  Puerto Rico           PR  under18  2004   1035919.0
# 2476  Puerto Rico           PR    total  2003   3826095.0
# 2477  Puerto Rico           PR  under18  2003   1050615.0
# 2478  Puerto Rico           PR    total  2005   3821362.0
# 2479  Puerto Rico           PR  under18  2005   1019447.0
# 2480  Puerto Rico           PR    total  2006   3805214.0
# 2481  Puerto Rico           PR  under18  2006    998543.0
# 2482  Puerto Rico           PR    total  2007   3782995.0
# 2483  Puerto Rico           PR  under18  2007    973613.0
# 2484  Puerto Rico           PR    total  2008   3760866.0
# 2485  Puerto Rico           PR  under18  2008    945705.0
# 2486  Puerto Rico           PR  under18  2013    814068.0
# 2487  Puerto Rico           PR    total  2013   3615086.0
# 2488  Puerto Rico           PR    total  2009   3740410.0
# 2489  Puerto Rico           PR  under18  2009    920794.0
# 2490  Puerto Rico           PR    total  2010   3721208.0
# 2491  Puerto Rico           PR  under18  2010    896945.0
# 2492  Puerto Rico           PR  under18  2011    869327.0
# 2493  Puerto Rico           PR    total  2011   3686580.0
# 2494  Puerto Rico           PR  under18  2012    841740.0
# 2495  Puerto Rico           PR    total  2012   3651545.0

# %%
# 填补USA
pop2["state"][pop2["state/region"] == "USA"] = "United States"
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
pop2.isnull().any()
# Out:
# state           False
# state/region    False
# ages            False
# year            False
# population       True
# dtype: bool

# %% [markdown]
# 处理人口缺失问题

# %%
cond_pop = pop2["population"].isnull()

# %%
pop2[cond_pop]
# Out:
#             state state/region     ages  year  population
# 2448  Puerto Rico           PR  under18  1990         NaN
# 2449  Puerto Rico           PR    total  1990         NaN
# 2450  Puerto Rico           PR    total  1991         NaN
# 2451  Puerto Rico           PR  under18  1991         NaN
# 2452  Puerto Rico           PR    total  1993         NaN
# 2453  Puerto Rico           PR  under18  1993         NaN
# 2454  Puerto Rico           PR  under18  1992         NaN
# 2455  Puerto Rico           PR    total  1992         NaN
# 2456  Puerto Rico           PR  under18  1994         NaN
# 2457  Puerto Rico           PR    total  1994         NaN
# 2458  Puerto Rico           PR    total  1995         NaN
# 2459  Puerto Rico           PR  under18  1995         NaN
# 2460  Puerto Rico           PR  under18  1996         NaN
# 2461  Puerto Rico           PR    total  1996         NaN
# 2462  Puerto Rico           PR  under18  1998         NaN
# 2463  Puerto Rico           PR    total  1998         NaN
# 2464  Puerto Rico           PR    total  1997         NaN
# 2465  Puerto Rico           PR  under18  1997         NaN
# 2466  Puerto Rico           PR    total  1999         NaN
# 2467  Puerto Rico           PR  under18  1999         NaN

# %%
pop2.dropna(inplace=True)

# %%
pop2.isnull().any()
# Out:
# state           False
# state/region    False
# ages            False
# year            False
# population      False
# dtype: bool

# %% [markdown]
# 合并面积areas表

# %%
pop3 = pop2.merge(areas,how="outer")
pop3
# Out:
#               state state/region     ages  year   population  area (sq. mi)
# 0           Alabama           AL  under18  2012    1117489.0        52423.0
# 1           Alabama           AL    total  2012    4817528.0        52423.0
# 2           Alabama           AL  under18  2010    1130966.0        52423.0
# 3           Alabama           AL    total  2010    4785570.0        52423.0
# 4           Alabama           AL  under18  2011    1125763.0        52423.0
# 5           Alabama           AL    total  2011    4801627.0        52423.0
# 6           Alabama           AL    total  2009    4757938.0        52423.0
# 7           Alabama           AL  under18  2009    1134192.0        52423.0
# 8           Alabama           AL  under18  2013    1111481.0        52423.0
# 9           Alabama           AL    total  2013    4833722.0        52423.0
# 10          Alabama           AL    total  2007    4672840.0        52423.0
# 11          Alabama           AL  under18  2007    1132296.0        52423.0
# 12          Alabama           AL    total  2008    4718206.0        52423.0
# 13          Alabama           AL  under18  2008    1134927.0        52423.0
# 14          Alabama           AL    total  2005    4569805.0        52423.0
# 15          Alabama           AL  under18  2005    1117229.0        52423.0
# 16          Alabama           AL    total  2006    4628981.0        52423.0
# 17          Alabama           AL  under18  2006    1126798.0        52423.0
# 18          Alabama           AL    total  2004    4530729.0        52423.0
# 19          Alabama           AL  under18  2004    1113662.0        52423.0
# 20          Alabama           AL    total  2003    4503491.0        52423.0
# 21          Alabama           AL  under18  2003    1113083.0        52423.0
# 22          Alabama           AL    total  2001    4467634.0        52423.0
# 23          Alabama           AL  under18  2001    1120409.0        52423.0
# 24          Alabama           AL    total  2002    4480089.0        52423.0
# 25          Alabama           AL  under18  2002    1116590.0        52423.0
# 26          Alabama           AL  under18  1999    1121287.0        52423.0
# 27          Alabama           AL    total  1999    4430141.0        52423.0
# 28          Alabama           AL    total  2000    4452173.0        52423.0
# 29          Alabama           AL  under18  2000    1122273.0        52423.0
# ...             ...          ...      ...   ...          ...            ...
# 2494  United States          USA  under18  1999   71946051.0            NaN
# 2495  United States          USA    total  2000  282162411.0            NaN
# 2496  United States          USA  under18  2000   72376189.0            NaN
# 2497  United States          USA    total  1999  279040181.0            NaN
# 2498  United States          USA    total  2001  284968955.0            NaN
# 2499  United States          USA  under18  2001   72671175.0            NaN
# 2500  United States          USA    total  2002  287625193.0            NaN
# 2501  United States          USA  under18  2002   72936457.0            NaN
# 2502  United States          USA    total  2003  290107933.0            NaN
# 2503  United States          USA  under18  2003   73100758.0            NaN
# 2504  United States          USA    total  2004  292805298.0            NaN
# 2505  United States          USA  under18  2004   73297735.0            NaN
# 2506  United States          USA    total  2005  295516599.0            NaN
# 2507  United States          USA  under18  2005   73523669.0            NaN
# 2508  United States          USA    total  2006  298379912.0            NaN
# 2509  United States          USA  under18  2006   73757714.0            NaN
# 2510  United States          USA    total  2007  301231207.0            NaN
# 2511  United States          USA  under18  2007   74019405.0            NaN
# 2512  United States          USA    total  2008  304093966.0            NaN
# 2513  United States          USA  under18  2008   74104602.0            NaN
# 2514  United States          USA  under18  2013   73585872.0            NaN
# 2515  United States          USA    total  2013  316128839.0            NaN
# 2516  United States          USA    total  2009  306771529.0            NaN
# 2517  United States          USA  under18  2009   74134167.0            NaN
# 2518  United States          USA  under18  2010   74119556.0            NaN
# 2519  United States          USA    total  2010  309326295.0            NaN
# 2520  United States          USA  under18  2011   73902222.0            NaN
# 2521  United States          USA    total  2011  311582564.0            NaN
# 2522  United States          USA  under18  2012   73708179.0            NaN
# 2523  United States          USA    total  2012  313873685.0            NaN
#
# [2524 rows x 6 columns]

# %% [markdown]
# USA的面积缺失，通过分析可以加出来

# %%
usa_area = areas["area (sq. mi)"].sum()
usa_area
# Out:
# 3790399

# %%
pop3["area (sq. mi)"][pop3["state/region"] == "USA"] = usa_area
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
pop3.isnull().any()
# Out:
# state            False
# state/region     False
# ages             False
# year             False
# population       False
# area (sq. mi)    False
# dtype: bool

# %% [markdown]
# 经过以上的处理，数据已经整合并且清洗完毕
#
# 接下来对pop3中的数据进行分析与挖掘

# %% [markdown]
# 1、查询2012年的每个州的全民人口数据

# %%
pop3.head()
# Out:
#      state state/region     ages  year  population  area (sq. mi)
# 0  Alabama           AL  under18  2012   1117489.0        52423.0
# 1  Alabama           AL    total  2012   4817528.0        52423.0
# 2  Alabama           AL  under18  2010   1130966.0        52423.0
# 3  Alabama           AL    total  2010   4785570.0        52423.0
# 4  Alabama           AL  under18  2011   1125763.0        52423.0

# %%
pop_2012 = pop3.query("ages=='total' & year==2012")
pop_2012
# Out:
#                      state state/region   ages  year   population  \
# 1                  Alabama           AL  total  2012    4817528.0
# 95                  Alaska           AK  total  2012     730307.0
# 97                 Arizona           AZ  total  2012    6551149.0
# 191               Arkansas           AR  total  2012    2949828.0
# 193             California           CA  total  2012   37999878.0
# 287               Colorado           CO  total  2012    5189458.0
# 289            Connecticut           CT  total  2012    3591765.0
# 383               Delaware           DE  total  2012     917053.0
# 385   District of Columbia           DC  total  2012     633427.0
# 479                Florida           FL  total  2012   19320749.0
# 480                Georgia           GA  total  2012    9915646.0
# 575                 Hawaii           HI  total  2012    1390090.0
# 576                  Idaho           ID  total  2012    1595590.0
# 671               Illinois           IL  total  2012   12868192.0
# 672                Indiana           IN  total  2012    6537782.0
# 767                   Iowa           IA  total  2012    3075039.0
# 768                 Kansas           KS  total  2012    2885398.0
# 863               Kentucky           KY  total  2012    4379730.0
# 864              Louisiana           LA  total  2012    4602134.0
# 959                  Maine           ME  total  2012    1328501.0
# 960                Montana           MT  total  2012    1005494.0
# 1055              Nebraska           NE  total  2012    1855350.0
# 1056                Nevada           NV  total  2012    2754354.0
# 1151         New Hampshire           NH  total  2012    1321617.0
# 1152            New Jersey           NJ  total  2012    8867749.0
# 1247            New Mexico           NM  total  2012    2083540.0
# 1248              New York           NY  total  2012   19576125.0
# 1343        North Carolina           NC  total  2012    9748364.0
# 1344          North Dakota           ND  total  2012     701345.0
# 1439                  Ohio           OH  total  2012   11553031.0
# 1440              Oklahoma           OK  total  2012    3815780.0
# 1535                Oregon           OR  total  2012    3899801.0
# 1536              Maryland           MD  total  2012    5884868.0
# 1631         Massachusetts           MA  total  2012    6645303.0
# 1632              Michigan           MI  total  2012    9882519.0
# 1727             Minnesota           MN  total  2012    5379646.0
# 1728           Mississippi           MS  total  2012    2986450.0
# 1823              Missouri           MO  total  2012    6024522.0
# 1824          Pennsylvania           PA  total  2012   12764475.0
# 1919          Rhode Island           RI  total  2012    1050304.0
# 1920        South Carolina           SC  total  2012    4723417.0
# 2015          South Dakota           SD  total  2012     834047.0
# 2016             Tennessee           TN  total  2012    6454914.0
# 2111                 Texas           TX  total  2012   26060796.0
# 2112                  Utah           UT  total  2012    2854871.0
# 2207               Vermont           VT  total  2012     625953.0
# 2208              Virginia           VA  total  2012    8186628.0
# 2303            Washington           WA  total  2012    6895318.0
# 2304         West Virginia           WV  total  2012    1856680.0
# 2399             Wisconsin           WI  total  2012    5724554.0
# 2400               Wyoming           WY  total  2012     576626.0
# 2475           Puerto Rico           PR  total  2012    3651545.0
# 2523         United States          USA  total  2012  313873685.0
#
#       area (sq. mi)
# 1           52423.0
# 95         656425.0
# 97         114006.0
# 191         53182.0
# 193        163707.0
# 287        104100.0
# 289          5544.0
# 383          1954.0
# 385            68.0
# 479         65758.0
# 480         59441.0
# 575         10932.0
# 576         83574.0
# 671         57918.0
# 672         36420.0
# 767         56276.0
# 768         82282.0
# 863         40411.0
# 864         51843.0
# 959         35387.0
# 960        147046.0
# 1055        77358.0
# 1056       110567.0
# 1151         9351.0
# 1152         8722.0
# 1247       121593.0
# 1248        54475.0
# 1343        53821.0
# 1344        70704.0
# 1439        44828.0
# 1440        69903.0
# 1535        98386.0
# 1536        12407.0
# 1631        10555.0
# 1632        96810.0
# 1727        86943.0
# 1728        48434.0
# 1823        69709.0
# 1824        46058.0
# 1919         1545.0
# 1920        32007.0
# 2015        77121.0
# 2016        42146.0
# 2111       268601.0
# 2112        84904.0
# 2207         9615.0
# 2208        42769.0
# 2303        71303.0
# 2304        24231.0
# 2399        65503.0
# 2400        97818.0
# 2475         3515.0
# 2523      3790399.0

# %% [markdown]
# 2、对查询下结果处理，用state作为新的索引

# %%
pop_2012.set_index("state",inplace=True)

# %%
pop_2012
# Out:
#                      state/region   ages  year   population  area (sq. mi)
# state
# Alabama                        AL  total  2012    4817528.0        52423.0
# Alaska                         AK  total  2012     730307.0       656425.0
# Arizona                        AZ  total  2012    6551149.0       114006.0
# Arkansas                       AR  total  2012    2949828.0        53182.0
# California                     CA  total  2012   37999878.0       163707.0
# Colorado                       CO  total  2012    5189458.0       104100.0
# Connecticut                    CT  total  2012    3591765.0         5544.0
# Delaware                       DE  total  2012     917053.0         1954.0
# District of Columbia           DC  total  2012     633427.0           68.0
# Florida                        FL  total  2012   19320749.0        65758.0
# Georgia                        GA  total  2012    9915646.0        59441.0
# Hawaii                         HI  total  2012    1390090.0        10932.0
# Idaho                          ID  total  2012    1595590.0        83574.0
# Illinois                       IL  total  2012   12868192.0        57918.0
# Indiana                        IN  total  2012    6537782.0        36420.0
# Iowa                           IA  total  2012    3075039.0        56276.0
# Kansas                         KS  total  2012    2885398.0        82282.0
# Kentucky                       KY  total  2012    4379730.0        40411.0
# Louisiana                      LA  total  2012    4602134.0        51843.0
# Maine                          ME  total  2012    1328501.0        35387.0
# Montana                        MT  total  2012    1005494.0       147046.0
# Nebraska                       NE  total  2012    1855350.0        77358.0
# Nevada                         NV  total  2012    2754354.0       110567.0
# New Hampshire                  NH  total  2012    1321617.0         9351.0
# New Jersey                     NJ  total  2012    8867749.0         8722.0
# New Mexico                     NM  total  2012    2083540.0       121593.0
# New York                       NY  total  2012   19576125.0        54475.0
# North Carolina                 NC  total  2012    9748364.0        53821.0
# North Dakota                   ND  total  2012     701345.0        70704.0
# Ohio                           OH  total  2012   11553031.0        44828.0
# Oklahoma                       OK  total  2012    3815780.0        69903.0
# Oregon                         OR  total  2012    3899801.0        98386.0
# Maryland                       MD  total  2012    5884868.0        12407.0
# Massachusetts                  MA  total  2012    6645303.0        10555.0
# Michigan                       MI  total  2012    9882519.0        96810.0
# Minnesota                      MN  total  2012    5379646.0        86943.0
# Mississippi                    MS  total  2012    2986450.0        48434.0
# Missouri                       MO  total  2012    6024522.0        69709.0
# Pennsylvania                   PA  total  2012   12764475.0        46058.0
# Rhode Island                   RI  total  2012    1050304.0         1545.0
# South Carolina                 SC  total  2012    4723417.0        32007.0
# South Dakota                   SD  total  2012     834047.0        77121.0
# Tennessee                      TN  total  2012    6454914.0        42146.0
# Texas                          TX  total  2012   26060796.0       268601.0
# Utah                           UT  total  2012    2854871.0        84904.0
# Vermont                        VT  total  2012     625953.0         9615.0
# Virginia                       VA  total  2012    8186628.0        42769.0
# Washington                     WA  total  2012    6895318.0        71303.0
# West Virginia                  WV  total  2012    1856680.0        24231.0
# Wisconsin                      WI  total  2012    5724554.0        65503.0
# Wyoming                        WY  total  2012     576626.0        97818.0
# Puerto Rico                    PR  total  2012    3651545.0         3515.0
# United States                 USA  total  2012  313873685.0      3790399.0

# %%
pop_2012["state"] # state现在是索引，而不是属性
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2441             try:
# -> 2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'state'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-219-a54e55db9843> in <module>()
# ----> 1 pop_2012["state"] # state现在是索引，而不是属性
#
# C:\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    1962             return self._getitem_multilevel(key)
#    1963         else:
# -> 1964             return self._getitem_column(key)
#    1965
#    1966     def _getitem_column(self, key):
#
# C:\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    1969         # get column
#    1970         if self.columns.is_unique:
# -> 1971             return self._get_item_cache(key)
#    1972
#    1973         # duplicate columns & possible reduce dimensionality
#
# C:\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    1643         res = cache.get(item)
#    1644         if res is None:
# -> 1645             values = self._data.get(item)
#    1646             res = self._box_item_values(item, values)
#    1647             cache[item] = res
#
# C:\Anaconda3\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    3588
#    3589             if not isnull(item):
# -> 3590                 loc = self.items.get_loc(item)
#    3591             else:
#    3592                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# C:\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
# -> 2444                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2445
#    2446         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'state'

# %% [markdown]
# 3、计算各州的2012年人口密度

# %%
des = pop_2012["population"] / pop_2012["area (sq. mi)"]
des
# Out:
# state
# Alabama                   91.897221
# Alaska                     1.112552
# Arizona                   57.463195
# Arkansas                  55.466662
# California               232.121278
# Colorado                  49.850701
# Connecticut              647.865260
# Delaware                 469.320880
# District of Columbia    9315.102941
# Florida                  293.815946
# Georgia                  166.814926
# Hawaii                   127.157885
# Idaho                     19.091942
# Illinois                 222.179495
# Indiana                  179.510763
# Iowa                      54.642103
# Kansas                    35.067184
# Kentucky                 108.379649
# Louisiana                 88.770596
# Maine                     37.542063
# Montana                    6.837955
# Nebraska                  23.983945
# Nevada                    24.911176
# New Hampshire            141.334296
# New Jersey              1016.710502
# New Mexico                17.135361
# New York                 359.359798
# North Carolina           181.125657
# North Dakota               9.919453
# Ohio                     257.719082
# Oklahoma                  54.586785
# Oregon                    39.637764
# Maryland                 474.318369
# Massachusetts            629.588157
# Michigan                 102.081593
# Minnesota                 61.875551
# Mississippi               61.660197
# Missouri                  86.423876
# Pennsylvania             277.139151
# Rhode Island             679.808414
# South Carolina           147.574499
# South Dakota              10.814785
# Tennessee                153.156029
# Texas                     97.024196
# Utah                      33.624694
# Vermont                   65.101716
# Virginia                 191.414997
# Washington                96.704458
# West Virginia             76.624159
# Wisconsin                 87.393768
# Wyoming                    5.894886
# Puerto Rico             1038.846373
# United States             82.807558
# dtype: float64

# %%
des_df = DataFrame(des,columns=["densey (人/sq.mi)"])
des_df
# Out:
#                       densey (人/sq.mi)
# state
# Alabama                      91.897221
# Alaska                        1.112552
# Arizona                      57.463195
# Arkansas                     55.466662
# California                  232.121278
# Colorado                     49.850701
# Connecticut                 647.865260
# Delaware                    469.320880
# District of Columbia       9315.102941
# Florida                     293.815946
# Georgia                     166.814926
# Hawaii                      127.157885
# Idaho                        19.091942
# Illinois                    222.179495
# Indiana                     179.510763
# Iowa                         54.642103
# Kansas                       35.067184
# Kentucky                    108.379649
# Louisiana                    88.770596
# Maine                        37.542063
# Montana                       6.837955
# Nebraska                     23.983945
# Nevada                       24.911176
# New Hampshire               141.334296
# New Jersey                 1016.710502
# New Mexico                   17.135361
# New York                    359.359798
# North Carolina              181.125657
# North Dakota                  9.919453
# Ohio                        257.719082
# Oklahoma                     54.586785
# Oregon                       39.637764
# Maryland                    474.318369
# Massachusetts               629.588157
# Michigan                    102.081593
# Minnesota                    61.875551
# Mississippi                  61.660197
# Missouri                     86.423876
# Pennsylvania                277.139151
# Rhode Island                679.808414
# South Carolina              147.574499
# South Dakota                 10.814785
# Tennessee                   153.156029
# Texas                        97.024196
# Utah                         33.624694
# Vermont                      65.101716
# Virginia                    191.414997
# Washington                   96.704458
# West Virginia                76.624159
# Wisconsin                    87.393768
# Wyoming                       5.894886
# Puerto Rico                1038.846373
# United States                82.807558

# %%
# 把人口密度拼接到pop_2012上面
pop_2012_dens = pd.merge(pop_2012,des_df,left_index=True,right_index=True)

# %%
pop_2012_dens.head()
# Out:
#            state/region   ages  year  population  area (sq. mi)  \
# state
# Alabama              AL  total  2012   4817528.0        52423.0
# Alaska               AK  total  2012    730307.0       656425.0
# Arizona              AZ  total  2012   6551149.0       114006.0
# Arkansas             AR  total  2012   2949828.0        53182.0
# California           CA  total  2012  37999878.0       163707.0
#
#             densey (人/sq.mi)
# state
# Alabama            91.897221
# Alaska              1.112552
# Arizona            57.463195
# Arkansas           55.466662
# California        232.121278

# %% [markdown]
# 4、排序、并且求密度最高的五个州和密度最低的五个州

# %%
pop_2012_dens.sort_values("densey (人/sq.mi)",inplace=True)

# %%
pop_2012_dens
# Out:
#                      state/region   ages  year   population  area (sq. mi)  \
# state
# Alaska                         AK  total  2012     730307.0       656425.0
# Wyoming                        WY  total  2012     576626.0        97818.0
# Montana                        MT  total  2012    1005494.0       147046.0
# North Dakota                   ND  total  2012     701345.0        70704.0
# South Dakota                   SD  total  2012     834047.0        77121.0
# New Mexico                     NM  total  2012    2083540.0       121593.0
# Idaho                          ID  total  2012    1595590.0        83574.0
# Nebraska                       NE  total  2012    1855350.0        77358.0
# Nevada                         NV  total  2012    2754354.0       110567.0
# Utah                           UT  total  2012    2854871.0        84904.0
# Kansas                         KS  total  2012    2885398.0        82282.0
# Maine                          ME  total  2012    1328501.0        35387.0
# Oregon                         OR  total  2012    3899801.0        98386.0
# Colorado                       CO  total  2012    5189458.0       104100.0
# Oklahoma                       OK  total  2012    3815780.0        69903.0
# Iowa                           IA  total  2012    3075039.0        56276.0
# Arkansas                       AR  total  2012    2949828.0        53182.0
# Arizona                        AZ  total  2012    6551149.0       114006.0
# Mississippi                    MS  total  2012    2986450.0        48434.0
# Minnesota                      MN  total  2012    5379646.0        86943.0
# Vermont                        VT  total  2012     625953.0         9615.0
# West Virginia                  WV  total  2012    1856680.0        24231.0
# United States                 USA  total  2012  313873685.0      3790399.0
# Missouri                       MO  total  2012    6024522.0        69709.0
# Wisconsin                      WI  total  2012    5724554.0        65503.0
# Louisiana                      LA  total  2012    4602134.0        51843.0
# Alabama                        AL  total  2012    4817528.0        52423.0
# Washington                     WA  total  2012    6895318.0        71303.0
# Texas                          TX  total  2012   26060796.0       268601.0
# Michigan                       MI  total  2012    9882519.0        96810.0
# Kentucky                       KY  total  2012    4379730.0        40411.0
# Hawaii                         HI  total  2012    1390090.0        10932.0
# New Hampshire                  NH  total  2012    1321617.0         9351.0
# South Carolina                 SC  total  2012    4723417.0        32007.0
# Tennessee                      TN  total  2012    6454914.0        42146.0
# Georgia                        GA  total  2012    9915646.0        59441.0
# Indiana                        IN  total  2012    6537782.0        36420.0
# North Carolina                 NC  total  2012    9748364.0        53821.0
# Virginia                       VA  total  2012    8186628.0        42769.0
# Illinois                       IL  total  2012   12868192.0        57918.0
# California                     CA  total  2012   37999878.0       163707.0
# Ohio                           OH  total  2012   11553031.0        44828.0
# Pennsylvania                   PA  total  2012   12764475.0        46058.0
# Florida                        FL  total  2012   19320749.0        65758.0
# New York                       NY  total  2012   19576125.0        54475.0
# Delaware                       DE  total  2012     917053.0         1954.0
# Maryland                       MD  total  2012    5884868.0        12407.0
# Massachusetts                  MA  total  2012    6645303.0        10555.0
# Connecticut                    CT  total  2012    3591765.0         5544.0
# Rhode Island                   RI  total  2012    1050304.0         1545.0
# New Jersey                     NJ  total  2012    8867749.0         8722.0
# Puerto Rico                    PR  total  2012    3651545.0         3515.0
# District of Columbia           DC  total  2012     633427.0           68.0
#
#                       densey (人/sq.mi)
# state
# Alaska                        1.112552
# Wyoming                       5.894886
# Montana                       6.837955
# North Dakota                  9.919453
# South Dakota                 10.814785
# New Mexico                   17.135361
# Idaho                        19.091942
# Nebraska                     23.983945
# Nevada                       24.911176
# Utah                         33.624694
# Kansas                       35.067184
# Maine                        37.542063
# Oregon                       39.637764
# Colorado                     49.850701
# Oklahoma                     54.586785
# Iowa                         54.642103
# Arkansas                     55.466662
# Arizona                      57.463195
# Mississippi                  61.660197
# Minnesota                    61.875551
# Vermont                      65.101716
# West Virginia                76.624159
# United States                82.807558
# Missouri                     86.423876
# Wisconsin                    87.393768
# Louisiana                    88.770596
# Alabama                      91.897221
# Washington                   96.704458
# Texas                        97.024196
# Michigan                    102.081593
# Kentucky                    108.379649
# Hawaii                      127.157885
# New Hampshire               141.334296
# South Carolina              147.574499
# Tennessee                   153.156029
# Georgia                     166.814926
# Indiana                     179.510763
# North Carolina              181.125657
# Virginia                    191.414997
# Illinois                    222.179495
# California                  232.121278
# Ohio                        257.719082
# Pennsylvania                277.139151
# Florida                     293.815946
# New York                    359.359798
# Delaware                    469.320880
# Maryland                    474.318369
# Massachusetts               629.588157
# Connecticut                 647.865260
# Rhode Island                679.808414
# New Jersey                 1016.710502
# Puerto Rico                1038.846373
# District of Columbia       9315.102941

# %%
pop_2012_dens.head(5)
# Out:
#              state/region   ages  year  population  area (sq. mi)  \
# state
# Alaska                 AK  total  2012    730307.0       656425.0
# Wyoming                WY  total  2012    576626.0        97818.0
# Montana                MT  total  2012   1005494.0       147046.0
# North Dakota           ND  total  2012    701345.0        70704.0
# South Dakota           SD  total  2012    834047.0        77121.0
#
#               densey (人/sq.mi)
# state
# Alaska                1.112552
# Wyoming               5.894886
# Montana               6.837955
# North Dakota          9.919453
# South Dakota         10.814785

# %%
pop_2012_dens.tail().loc[::-1]
# Out:
#                      state/region   ages  year  population  area (sq. mi)  \
# state
# District of Columbia           DC  total  2012    633427.0           68.0
# Puerto Rico                    PR  total  2012   3651545.0         3515.0
# New Jersey                     NJ  total  2012   8867749.0         8722.0
# Rhode Island                   RI  total  2012   1050304.0         1545.0
# Connecticut                    CT  total  2012   3591765.0         5544.0
#
#                       densey (人/sq.mi)
# state
# District of Columbia       9315.102941
# Puerto Rico                1038.846373
# New Jersey                 1016.710502
# Rhode Island                679.808414
# Connecticut                 647.865260

# %% [markdown]
# ## 回顾：Series/DataFrame运算与ndarray运算的区别

# %% [markdown]
# - Series与DataFrame没有广播，如果对应index没有值，则记为NaN；或者使用add的fill_value来补缺失值
# - ndarray有广播，通过重复已有值来计算
