# %% [markdown]
# # pandas数据处理

# %%
import numpy as np
import pandas as pd
from pandas import Series,DataFrame

# %% [markdown]
# ## 1、删除重复元素

# %%
df = DataFrame({
    "name":["Jack","xiaoming","xiaohuang","xiaoming","laowang","laozhang","laowang"],
    "score":[120,100,100,50,90,100,90]
})
df
# Out:
#         name  score
# 0       Jack    120
# 1   xiaoming    100
# 2  xiaohuang    100
# 3   xiaoming     50
# 4    laowang     90
# 5   laozhang    100
# 6    laowang     90

# %% [markdown]
# 检测重复，duplicated(),返回值是一个Series，记录某一行是否重复，如果这一行不是第一次出现，就认为是重复

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6     True
# dtype: bool

# %% [markdown]
# 删除重复，drop_duplicates()

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#         name  score
# 0       Jack    120
# 1   xiaoming    100
# 2  xiaohuang    100
# 3   xiaoming     50
# 4    laowang     90
# 5   laozhang    100

# %%
df1 = pd.concat([df,df],axis=1)
df1
# Out:
#         name  score       name  score
# 0       Jack    120       Jack    120
# 1   xiaoming    100   xiaoming    100
# 2  xiaohuang    100  xiaohuang    100
# 3   xiaoming     50   xiaoming     50
# 4    laowang     90    laowang     90
# 5   laozhang    100   laozhang    100

# %%
df1.duplicated() # 如果列上有重复，这个方法不能用
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-63-862c1b17f1a5> in <module>()
# ----> 1 df1.duplicated() # 如果列上有重复，这个方法不能用
#
# C:\Anaconda3\lib\site-packages\pandas\core\frame.py in duplicated(self, subset, keep)
#    3142
#    3143         vals = (self[col].values for col in subset)
# -> 3144         labels, shape = map(list, zip(*map(f, vals)))
#    3145
#    3146         ids = get_group_index(labels, shape, sort=False, xnull=False)
#
# C:\Anaconda3\lib\site-packages\pandas\core\frame.py in f(vals)
#    3131         def f(vals):
#    3132             labels, shape = algorithms.factorize(
# -> 3133                 vals, size_hint=min(len(self), _SIZE_HINT_LIMIT))
#    3134             return labels.astype('i8', copy=False), len(shape)
#    3135
#
# C:\Anaconda3\lib\site-packages\pandas\core\algorithms.py in factorize(values, sort, order, na_sentinel, size_hint)
#     558     uniques = vec_klass()
#     559     check_nulls = not is_integer_dtype(original)
# --> 560     labels = table.get_labels(values, uniques, 0, na_sentinel, check_nulls)
#     561
#     562     labels = _ensure_platform_int(labels)
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.StringHashTable.get_labels()
#
# ValueError: Buffer has wrong number of dimensions (expected 1, got 2)

# %%
df1.drop_duplicates()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-64-817e25a941a3> in <module>()
# ----> 1 df1.drop_duplicates()
#
# C:\Anaconda3\lib\site-packages\pandas\core\frame.py in drop_duplicates(self, subset, keep, inplace)
#    3096         """
#    3097         inplace = validate_bool_kwarg(inplace, 'inplace')
# -> 3098         duplicated = self.duplicated(subset, keep=keep)
#    3099
#    3100         if inplace:
#
# C:\Anaconda3\lib\site-packages\pandas\core\frame.py in duplicated(self, subset, keep)
#    3142
#    3143         vals = (self[col].values for col in subset)
# -> 3144         labels, shape = map(list, zip(*map(f, vals)))
#    3145
#    3146         ids = get_group_index(labels, shape, sort=False, xnull=False)
#
# C:\Anaconda3\lib\site-packages\pandas\core\frame.py in f(vals)
#    3131         def f(vals):
#    3132             labels, shape = algorithms.factorize(
# -> 3133                 vals, size_hint=min(len(self), _SIZE_HINT_LIMIT))
#    3134             return labels.astype('i8', copy=False), len(shape)
#    3135
#
# C:\Anaconda3\lib\site-packages\pandas\core\algorithms.py in factorize(values, sort, order, na_sentinel, size_hint)
#     558     uniques = vec_klass()
#     559     check_nulls = not is_integer_dtype(original)
# --> 560     labels = table.get_labels(values, uniques, 0, na_sentinel, check_nulls)
#     561
#     562     labels = _ensure_platform_int(labels)
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.StringHashTable.get_labels()
#
# ValueError: Buffer has wrong number of dimensions (expected 1, got 2)

# %% [markdown]
# ## 2. 映射

# %% [markdown]
# 映射的含义：一个关系表，把某些值和某个特定的键绑定在一起
#
# 字典{"12":123,"w":laowang,"t":[1,2,43]}
#
# y = 2x+3
#
# def func(x,y):
#
#    print(x+y)
#    return x**y
# 一个函数，入口是参数，出口是返回值
# 由入口的参数映射到出口的返回值
#
# lambda x: x**2

# %% [markdown]
# ### 1) replace()函数：替换元素

# %%
df
# Out:
#         name  score
# 0       Jack    120
# 1   xiaoming    100
# 2  xiaohuang    100
# 3   xiaoming     50
# 4    laowang     90
# 5   laozhang    100

# %%
# 把所有的xiaoming替换成daming
df["name"][df["name"] == "xiaoming"] = "daming"
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df
# Out:
#         name  score
# 0       Jack    120
# 1     daming    100
# 2  xiaohuang    100
# 3     daming     50
# 4    laowang     90
# 5   laozhang    100

# %%
# 用映射的方式把daming替换成xiaoming
dic = {"daming":"xiaoming"}
df.replace(dic,inplace=True) 
# replace函数的作用：根据我们传过来的那个字典，把df表中能够和字典键匹配的那些值替换成
# 字典的值

# %%
df
# Out:
#         name  score
# 0       Jack    120
# 1   xiaoming    100
# 2  xiaohuang    100
# 3   xiaoming     50
# 4    laowang     90
# 5   laozhang    100

# %%
def func1(name):
    
    return "daming"

# %%
df.replace(func1) # replace函数只支持字典映射，不支持函数映射
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-71-dd5d5fc57773> in <module>()
# ----> 1 df.replace(func1) # replace函数只支持字典映射，不支持函数映射
#
# C:\Anaconda3\lib\site-packages\pandas\core\generic.py in replace(self, to_replace, value, inplace, limit, regex, method, axis)
#    3797             if isinstance(to_replace, (tuple, list)):
#    3798                 return _single_replace(self, to_replace, method, inplace,
# -> 3799                                        limit)
#    3800
#    3801             if not is_dict_like(to_replace):
#
# C:\Anaconda3\lib\site-packages\pandas\core\generic.py in _single_replace(self, to_replace, method, inplace, limit)
#      73     if self.ndim != 1:
#      74         raise TypeError('cannot replace {0} with method {1} on a {2}'
# ---> 75                         .format(to_replace, method, type(self).__name__))
#      76
#      77     orig_dtype = self.dtype
#
# TypeError: cannot replace [<function func1 at 0x000002322B7EF7B8>] with method pad on a DataFrame

# %% [markdown]
# ============================================
#
# 练习19：
#
#     假设张三李四的课表里有满分的情况，老师认为是作弊，把所有满分的情况（包括150,300分）都记0分，如何实现？
#
# ============================================

# %% [markdown]
# ### 2) map()函数：新建一列

# %%
df = DataFrame(np.random.randint(0,150,size=(4,4)),
               index=["张三","李四","达康","陈院长"],
               columns=["python","外语","数学","java"])
df
# Out:
#      python   外语   数学  java
# 张三       24   69   57    22
# 李四      127   43  100   111
# 达康       95  148  119     0
# 陈院长     142   90   59    51

# %%
# 用映射新增一列
score = {148:120,110:100,94:67,126:127,110:180}
df["go"] = df["python"] # 用python这一列生成了一个go这一列

df["go"] = df["python"].map(score) # 通过map函数可以将一列的内容映射出另一列一个series
df
# Out:
#      python   外语   数学  java  go
# 张三       24   69   57    22 NaN
# 李四      127   43  100   111 NaN
# 达康       95  148  119     0 NaN
# 陈院长     142   90   59    51 NaN

# %% [markdown]
# lambda函数映射

# %%
v = lambda x : x*2

# %%
v(10)
# Out:
# 20

# %%
df["外语"] = df["外语"].map(v) 
# 如果映射是一个函数，会把series里面所有的值依次取出，带入函数中，得到映射结果

# %%
df
# Out:
#      python   外语   数学  java  go
# 张三       24  138   57    22 NaN
# 李四      127   86  100   111 NaN
# 达康       95  296  119     0 NaN
# 陈院长     142  180   59    51 NaN

# %% [markdown]
# 用普通函数映射

# %%
def mp(x):
    if x > 120:
        return "优秀"
    elif x > 90:
        return "及格"
    else:
        return "不及格"

# %%
df["数学成绩"] = df["数学"].map(mp)

# %%
df
# Out:
#      python   外语   数学  java  go 数学成绩
# 张三       24  138   57    22 NaN  不及格
# 李四      127   86  100   111 NaN   及格
# 达康       95  296  119     0 NaN   及格
# 陈院长     142  180   59    51 NaN  不及格

# %% [markdown]
# ============================================
#
# 练习20：
#
# 新增两列，分别为张三、李四的成绩状态，如果分数低于90，则为"failed"，如果分数高于120，则为"excellent"，其他则为"pass"
#
# 【提示】使用函数作为map的参数
#
# ============================================

# %% [markdown]
# ### 3) rename()函数：替换索引

# %%
df
# Out:
#      python   外语   数学  java  go 数学成绩
# 张三       24  138   57    22 NaN  不及格
# 李四      127   86  100   111 NaN   及格
# 达康       95  296  119     0 NaN   及格
# 陈院长     142  180   59    51 NaN  不及格

# %%
cols = {"外语":"English"}
rows = {"陈院长":"MrChen"}

# %%
df.rename(rows,cols)
# 第一个参数是指替换行的那个映射
# 第二个参数替换列的那个映射
# Out:
#         python  English   数学  java  go 数学成绩
# 张三          24      138   57    22 NaN  不及格
# 李四         127       86  100   111 NaN   及格
# 达康          95      296  119     0 NaN   及格
# MrChen     142      180   59    51 NaN  不及格

# %%
def func2(x):
    return "李富贵"

# %%
df.rename(columns=func2,index=func2)
# Out:
#      李富贵  李富贵  李富贵  李富贵 李富贵  李富贵
# 李富贵   24  138   57   22 NaN  不及格
# 李富贵  127   86  100  111 NaN   及格
# 李富贵   95  296  119    0 NaN   及格
# 李富贵  142  180   59   51 NaN  不及格

# %% [markdown]
# ## 3. 异常值检测和过滤

# %%
df = DataFrame(np.random.randint(0,100,size=(4,4)),
               index=["LiJiacheng","JackMa","Wangjianlin","MrFan"],
               columns=["money","age","score","yanzhi"])
df
# Out:
#              money  age  score  yanzhi
# LiJiacheng      18   14     42      54
# JackMa          21   53     21      57
# Wangjianlin     91   78     32      34
# MrFan           20    9     96      75

# %%
df.describe()
# 描述数据表属性相关的统计量
# Out:
#            money        age      score     yanzhi
# count   4.000000   4.000000   4.000000   4.000000
# mean   37.500000  38.500000  47.750000  55.000000
# std    35.688467  32.868425  33.290389  16.792856
# min    18.000000   9.000000  21.000000  34.000000
# 25%    19.500000  12.750000  29.250000  49.000000
# 50%    20.500000  33.500000  37.000000  55.500000
# 75%    38.500000  59.250000  55.500000  61.500000
# max    91.000000  78.000000  96.000000  75.000000

# %%
df.std(axis=0)
# Out:
# money     35.688467
# age       32.868425
# score     33.290389
# yanzhi    16.792856
# dtype: float64

# %%
df.mean(axis=1)
# Out:
# LiJiacheng     32.00
# JackMa         38.00
# Wangjianlin    58.75
# MrFan          50.00
# dtype: float64

# %% [markdown]
# 什么是异常值？根据需求来定义

# %%
# 定义大于标准差的2倍为异常值
cond = df>df.std()*2
cond # 符合异常条件都是True
# Out:
#              money    age  score  yanzhi
# LiJiacheng   False  False  False    True
# JackMa       False  False  False    True
# Wangjianlin   True   True  False    True
# MrFan        False  False   True    True

# %%
# 输出
df[cond]
# Out:
#              money   age  score  yanzhi
# LiJiacheng     NaN   NaN    NaN      54
# JackMa         NaN   NaN    NaN      57
# Wangjianlin   91.0  78.0    NaN      34
# MrFan          NaN   NaN   96.0      75

# %%
# 输出正常值
df1 = df[cond.replace({False:True,True:False})]
df1
# Out:
#              money   age  score  yanzhi
# LiJiacheng    18.0  14.0   42.0     NaN
# JackMa        21.0  53.0   21.0     NaN
# Wangjianlin    NaN   NaN   32.0     NaN
# MrFan         20.0   9.0    NaN     NaN

# %%
df1.dropna()
# Out:
# Empty DataFrame
# Columns: [money, age, score, yanzhi]
# Index: []

# %% [markdown]
# 处理异常：所有大于平均值2倍都是异常

# %%
# 1、根据过滤条件查找异常
cond = df > df.mean()*2
cond
# Out:
#              money    age  score  yanzhi
# LiJiacheng   False  False  False   False
# JackMa       False  False  False   False
# Wangjianlin   True   True  False   False
# MrFan        False  False   True   False

# %%
df2 = df[cond.replace({False:True,True:False})]
df2
# Out:
#              money   age  score  yanzhi
# LiJiacheng    18.0  14.0   42.0      54
# JackMa        21.0  53.0   21.0      57
# Wangjianlin    NaN   NaN   32.0      34
# MrFan         20.0   9.0    NaN      75

# %%
df2.dropna()
# Out:
#             money   age  score  yanzhi
# LiJiacheng   18.0  14.0   42.0      54
# JackMa       21.0  53.0   21.0      57

# %% [markdown]
# ============================================
#
# 练习21：
#
#     新建一个形状为10000*3的标准正态分布的DataFrame(np.random.randn)，去除掉所有满足以下情况的行：其中任一元素绝对值大于3倍标准差
#
# ============================================

# %%
df = DataFrame(np.random.randn(10000,3))
df
# Out:
#              0         1         2
# 0    -0.591876 -0.009506 -0.103773
# 1     0.390625 -1.798268  0.623583
# 2     0.040504 -0.072063  0.176879
# 3     0.136485  0.684327 -1.189321
# 4    -1.117789  0.516447 -2.366432
# 5     1.018096  1.431084 -0.095307
# 6     0.622351 -0.644622 -0.186716
# 7     0.391134 -1.439146 -0.218426
# 8    -1.071934 -0.167831  1.412367
# 9     1.985704  0.086298 -0.410040
# 10   -0.194608  0.417720 -0.150539
# 11   -0.536185 -0.265621 -0.545930
# 12   -0.869849  0.072220 -1.328358
# 13    0.000888  1.461253 -1.289116
# 14   -0.355737 -1.666662 -0.518214
# 15    0.063817  0.925436  0.045702
# 16   -0.675062  0.712955 -0.038684
# 17    1.472740 -1.432380  1.402332
# 18    1.405674  0.678154  0.838108
# 19    0.214665  1.189895 -0.232917
# 20   -0.204504  1.752996  0.134934
# 21   -1.438062 -1.340257  0.570062
# 22    0.688280  1.331032 -0.380653
# 23    0.486220 -0.315685 -0.870292
# 24    0.546259 -1.069952  0.836691
# 25    1.165169 -0.112182 -1.848606
# 26    1.794555 -1.040364  0.168892
# 27    0.028972 -1.190432  0.959198
# 28   -0.258311  0.422486 -0.148816
# 29   -0.777100 -0.917831  0.300200
# ...        ...       ...       ...
# 9970 -0.321149  0.192031 -0.513110
# 9971 -0.241198  1.321685  0.490816
# 9972 -0.107792  0.860083 -0.324764
# 9973  0.356835 -1.289713  0.879225
# 9974 -1.025985 -0.995642  1.263534
# 9975 -2.750928 -1.151876 -0.415081
# 9976  0.884244 -0.050094  0.721532
# 9977  0.647075  0.027333 -1.236495
# 9978  1.611153  1.057864 -0.773220
# 9979  0.389984 -1.311137 -0.604920
# 9980 -1.686233 -0.001914  0.167114
# 9981 -0.331263  0.160555  0.222842
# 9982  0.091103 -0.971324  0.074901
# 9983 -2.664339 -0.378407 -0.524392
# 9984  1.512239  1.779618 -0.766528
# 9985 -0.212880  1.258540  0.538440
# 9986 -0.051859  0.289303  1.122954
# 9987 -0.497368 -0.179821 -2.362407
# 9988  0.705598  0.845841 -1.733508
# 9989 -0.184066  0.292160  0.237682
# 9990 -1.542510 -0.272696 -0.073383
# 9991 -0.408996 -0.550264  0.956954
# 9992  1.743532  0.417737 -0.308434
# 9993  0.922526  0.475171  0.227454
# 9994 -0.813970  1.937342 -0.013650
# 9995 -1.065258  1.176484 -1.008098
# 9996  0.399148  0.468482 -0.256463
# 9997  0.804181 -1.317333  1.151828
# 9998  0.266202  1.465857  0.717452
# 9999 -0.917546  1.368005  1.840540
#
# [10000 rows x 3 columns]

# %%
cond = np.abs(df) > df.std()*3
cond
# Out:
#           0      1      2
# 0     False  False  False
# 1     False  False  False
# 2     False  False  False
# 3     False  False  False
# 4     False  False  False
# 5     False  False  False
# 6     False  False  False
# 7     False  False  False
# 8     False  False  False
# 9     False  False  False
# 10    False  False  False
# 11    False  False  False
# 12    False  False  False
# 13    False  False  False
# 14    False  False  False
# 15    False  False  False
# 16    False  False  False
# 17    False  False  False
# 18    False  False  False
# 19    False  False  False
# 20    False  False  False
# 21    False  False  False
# 22    False  False  False
# 23    False  False  False
# 24    False  False  False
# 25    False  False  False
# 26    False  False  False
# 27    False  False  False
# 28    False  False  False
# 29    False  False  False
# ...     ...    ...    ...
# 9970  False  False  False
# 9971  False  False  False
# 9972  False  False  False
# 9973  False  False  False
# 9974  False  False  False
# 9975  False  False  False
# 9976  False  False  False
# 9977  False  False  False
# 9978  False  False  False
# 9979  False  False  False
# 9980  False  False  False
# 9981  False  False  False
# 9982  False  False  False
# 9983  False  False  False
# 9984  False  False  False
# 9985  False  False  False
# 9986  False  False  False
# 9987  False  False  False
# 9988  False  False  False
# 9989  False  False  False
# 9990  False  False  False
# 9991  False  False  False
# 9992  False  False  False
# 9993  False  False  False
# 9994  False  False  False
# 9995  False  False  False
# 9996  False  False  False
# 9997  False  False  False
# 9998  False  False  False
# 9999  False  False  False
#
# [10000 rows x 3 columns]

# %%
df1 = df[cond.replace({False:True,True:False})]
df1
# Out:
#              0         1         2
# 0    -0.591876 -0.009506 -0.103773
# 1     0.390625 -1.798268  0.623583
# 2     0.040504 -0.072063  0.176879
# 3     0.136485  0.684327 -1.189321
# 4    -1.117789  0.516447 -2.366432
# 5     1.018096  1.431084 -0.095307
# 6     0.622351 -0.644622 -0.186716
# 7     0.391134 -1.439146 -0.218426
# 8    -1.071934 -0.167831  1.412367
# 9     1.985704  0.086298 -0.410040
# 10   -0.194608  0.417720 -0.150539
# 11   -0.536185 -0.265621 -0.545930
# 12   -0.869849  0.072220 -1.328358
# 13    0.000888  1.461253 -1.289116
# 14   -0.355737 -1.666662 -0.518214
# 15    0.063817  0.925436  0.045702
# 16   -0.675062  0.712955 -0.038684
# 17    1.472740 -1.432380  1.402332
# 18    1.405674  0.678154  0.838108
# 19    0.214665  1.189895 -0.232917
# 20   -0.204504  1.752996  0.134934
# 21   -1.438062 -1.340257  0.570062
# 22    0.688280  1.331032 -0.380653
# 23    0.486220 -0.315685 -0.870292
# 24    0.546259 -1.069952  0.836691
# 25    1.165169 -0.112182 -1.848606
# 26    1.794555 -1.040364  0.168892
# 27    0.028972 -1.190432  0.959198
# 28   -0.258311  0.422486 -0.148816
# 29   -0.777100 -0.917831  0.300200
# ...        ...       ...       ...
# 9970 -0.321149  0.192031 -0.513110
# 9971 -0.241198  1.321685  0.490816
# 9972 -0.107792  0.860083 -0.324764
# 9973  0.356835 -1.289713  0.879225
# 9974 -1.025985 -0.995642  1.263534
# 9975 -2.750928 -1.151876 -0.415081
# 9976  0.884244 -0.050094  0.721532
# 9977  0.647075  0.027333 -1.236495
# 9978  1.611153  1.057864 -0.773220
# 9979  0.389984 -1.311137 -0.604920
# 9980 -1.686233 -0.001914  0.167114
# 9981 -0.331263  0.160555  0.222842
# 9982  0.091103 -0.971324  0.074901
# 9983 -2.664339 -0.378407 -0.524392
# 9984  1.512239  1.779618 -0.766528
# 9985 -0.212880  1.258540  0.538440
# 9986 -0.051859  0.289303  1.122954
# 9987 -0.497368 -0.179821 -2.362407
# 9988  0.705598  0.845841 -1.733508
# 9989 -0.184066  0.292160  0.237682
# 9990 -1.542510 -0.272696 -0.073383
# 9991 -0.408996 -0.550264  0.956954
# 9992  1.743532  0.417737 -0.308434
# 9993  0.922526  0.475171  0.227454
# 9994 -0.813970  1.937342 -0.013650
# 9995 -1.065258  1.176484 -1.008098
# 9996  0.399148  0.468482 -0.256463
# 9997  0.804181 -1.317333  1.151828
# 9998  0.266202  1.465857  0.717452
# 9999 -0.917546  1.368005  1.840540
#
# [10000 rows x 3 columns]

# %%
df2 = df1.dropna()

# %%
df2.shape
# Out:
# (9924, 3)

# %% [markdown]
# ## 4. 随机排序

# %%
df1 = DataFrame(np.random.randint(0,100,size=(100,4)))
df1
# Out:
#      0   1   2   3
# 0   14  89  67  36
# 1   97  46  49  33
# 2   28  58  24  15
# 3   71   2  23  15
# 4    9  96  33  36
# 5   29  95  84  10
# 6   82  44  40  32
# 7   53  34   5  95
# 8   43  24  20  38
# 9   43   3  65  89
# 10  14   6  43  18
# 11  52  58  91  79
# 12   0  28  25  11
# 13  62  97  79   7
# 14  88  91  38  84
# 15  60  46  71  94
# 16  14  20  40  70
# 17  44  22   2  99
# 18  65  61  25  79
# 19  23  84  33   3
# 20  39  47   4  61
# 21  35  56  34  85
# 22  73  81  27  95
# 23  32  16  89  64
# 24  74  13  86  31
# 25  72  74  31  71
# 26  71   2  41  93
# 27  51  97  17  25
# 28  69  21  91  29
# 29   0  25  12  29
# ..  ..  ..  ..  ..
# 70  27  54  61  10
# 71  14   7  80   5
# 72  49  71  44  38
# 73  25   6  53  92
# 74  79  51  23  99
# 75   0  75  25  54
# 76  50  65  72  22
# 77  74  50  32  88
# 78  52  64  73  27
# 79  32  81   6  46
# 80  45   7  66  36
# 81  24  80  42  39
# 82  99  35   4  55
# 83  52   2  16  16
# 84  17  70  90  15
# 85  16  88  86   1
# 86   6   1   2   6
# 87  71  11  33  38
# 88  78  37   1   7
# 89  57  84  10  96
# 90  38  56  53  60
# 91  78  64  58  62
# 92  75  28  91  12
# 93  15  25  81  22
# 94  57  15  21  14
# 95  60  41  33  88
# 96  92  55  21  86
# 97  28  78  77  59
# 98  40   4   4  40
# 99  78  79  72  66
#
# [100 rows x 4 columns]

# %% [markdown]
# 1、随机打乱次序

# %%
ind = np.random.permutation(100)
ind
# Out:
# array([28, 83,  6, 62, 92, 18, 91, 71, 68,  3, 54, 80, 66, 34, 88, 98, 51,
#        29, 73, 47, 78, 64, 82, 31,  7, 26,  2, 27, 19, 85, 42, 65, 97, 89,
#        55, 25, 22, 17,  1, 94, 53, 77, 67, 44, 75, 59, 56, 37, 46,  0, 30,
#        99, 45, 13, 93, 69, 63, 81, 72, 40, 58, 41, 57, 87, 74, 21, 14, 50,
#         4, 95, 11, 48, 36, 39, 38, 52, 76, 32, 70, 43, 79, 84, 20, 61, 86,
#        33, 35,  8,  9, 90, 12,  5, 49, 96, 60, 15, 10, 23, 16, 24])

# %%
ind[30:40]
# Out:
# array([42, 65, 97, 89, 55, 25, 22, 17,  1, 94])

# %% [markdown]
# 2、在任意一个连续的区间中按照需求取样

# %%
df1.loc[ind[20:30]]
# Out:
#      0   1   2   3
# 78  52  64  73  27
# 64  88  71  30  68
# 82  99  35   4  55
# 31  81  61  75  86
# 7   53  34   5  95
# 26  71   2  41  93
# 2   28  58  24  15
# 27  51  97  17  25
# 19  23  84  33   3
# 85  16  88  86   1

# %%
df.take(ind[30:40])
# Out:
#            0         1         2
# 42  0.338968 -1.538887  0.895249
# 65 -0.638738  0.035171 -0.907494
# 97 -1.443040 -0.888129 -0.209660
# 89 -1.225739 -1.683341 -1.688559
# 55  0.502262 -2.146719  0.013832
# 25  1.165169 -0.112182 -1.848606
# 22  0.688280  1.331032 -0.380653
# 17  1.472740 -1.432380  1.402332
# 1   0.390625 -1.798268  0.623583
# 94  0.585316  0.086405 -2.547239

# %% [markdown]
# ============================================
# 练习22：
#
#    假设有张三李四王老五的期中考试成绩ddd2，对着三名同学随机排序
#
# ============================================

# %% [markdown]
# ## 5. 数据聚合【重点】

# %% [markdown]
# 分组聚合：
#
# 根据属性中值的不同先进行分组，然后再组内聚合
#
# 分组：根据某个属性的值进行分组
#
# 聚合：根据属性分组以后，对另外一个属性组内聚合
#
# 处理过程：分组=>聚合=>得到一个聚合以后的数据结构=>把得到的数据结构拼接到原表中
#
# 核心函数：groupby()

# %%
df = DataFrame({
    "item":["萝卜","白菜","辣椒","冬瓜","萝卜","萝卜","白菜","辣椒"],
    "color":["白","白","青","青","红","青","青","红"],
    "weight":np.random.randint(1,100,size=8),
    "price":np.random.randint(1,10,size=8)
})
df
# Out:
#   color item  price  weight
# 0     白   萝卜      4      88
# 1     白   白菜      6      75
# 2     青   辣椒      9      86
# 3     青   冬瓜      8      46
# 4     红   萝卜      9       6
# 5     青   萝卜      5      54
# 6     青   白菜      7       3
# 7     红   辣椒      3      96

# %%
df.sum()
# Out:
# color             白白青青红青青红
# item      萝卜白菜辣椒冬瓜萝卜萝卜白菜辣椒
# price                   51
# weight                 454
# dtype: object

# %%
df.mean()
# Out:
# price      6.375
# weight    56.750
# dtype: float64

# %%
df.var()
# Out:
# price        5.125000
# weight    1327.642857
# dtype: float64

# %% [markdown]
# 分组聚合

# %%
price_sum = df.groupby(["color"])[["price"]].sum()
price_sum
# Out:
#        price
# color
# 白         10
# 红         12
# 青         29

# %%
df.merge(price_sum,left_on="color",right_index=True,suffixes=["_单价","_总价"])
# Out:
#   color item  price_单价  weight  price_总价
# 0     白   萝卜         4      88        10
# 1     白   白菜         6      75        10
# 2     青   辣椒         9      86        29
# 3     青   冬瓜         8      46        29
# 5     青   萝卜         5      54        29
# 6     青   白菜         7       3        29
# 4     红   萝卜         9       6        12
# 7     红   辣椒         3      96        12

# %% [markdown]
# ============================================
#
# 练习23：
#
#    假设菜市场张大妈在卖菜，有以下属性：
#
#    菜品(item)：萝卜，白菜，辣椒，冬瓜
#
#    颜色(color)：白，青，红
#
#    重量(weight)
#
#    价格(price)
#
# 1. 要求以属性作为列索引，新建一个ddd
# 2. 对ddd进行聚合操作，求出颜色为白色的价格总和
# 3. 对ddd进行聚合操作，求出萝卜的所有重量(包括白萝卜，胡萝卜，青萝卜）以及平均价格
# 4. 使用merge合并总重量及平均价格
#
# ============================================

# %% [markdown]
# ## 6.0 高级数据聚合

# %% [markdown]
# 可以使用pd.merge()函数将聚合操作的计算结果添加到df的每一行
# 使用groupby分组后调用加和等函数进行运算，让后最后可以调用add_prefix()，来修改列名

# %% [markdown]
# ============================================
#
# 练习24：
#
#    使用transform与apply实现练习23的功能
#
# ============================================
